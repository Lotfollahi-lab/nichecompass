# %% [markdown]
# # Mouse CNS Spatial Reference Mapping Tutorial

# %% [markdown]
# - **Creator**: Sebastian Birk (<sebastian.birk@helmholtz-munich.de>).
# - **Affiliation:** Helmholtz Munich, Institute of AI for Health (AIH), Talavera-López Lab
# - **Date of Creation:** 18.05.2023
# - **Date of Last Modification:** 16.09.2026

# %% [markdown]
# In this tutorial we apply NicheCompass to integrate three samples (sagittal brain sections) of the STARmap PLUS mouse central nervous system dataset / atlas from [Shi, H. et al. Spatial atlas of the mouse central nervous system at molecular resolution. Nature 622, 552–561 (2023)](https://www.nature.com/articles/s41586-023-06569-5) in a spatial reference mapping setting (i.e. the model is first trained on the reference samples, and the query sample is then mapped onto the pretrained reference model by fine-tuning). The first two samples are used as reference samples and the third sample is the query.
#
# Sample 1 (reference) has:
# - 91,246 observations at cellular resolution with cell type annotations
# - 1022 probed genes
#
# Sample 2 (reference) has:
# - 123,836 observations at cellular resolution with cell type annotations
# - 1022 probed genes
#
# Sample 3 (query) has:
# - 207,591 observations at cellular resolution with cell type annotations
# - 1022 probed genes

# %% [markdown]
# The GP analysis walkthrough demonstrates automatic orientation, quality
# diagnostics, posterior activity uncertainty, signed feature arms, complete
# differential results and sample-aware communication. It requires the updated
# NicheCompass analysis API on `feature/zhang_ppi_gps`. See the
# [GP analysis guide](../../user_guide/gene_program_analysis.md) for API details.
# Saved publication outputs have been cleared; run the cells with the tutorial data
# to obtain outputs for your fitted model.

# %% [markdown]
# - Check the [documentation](https://nichecompass.readthedocs.io/en/latest/installation.html) for NicheCompass installation instructions.
# - The data for this tutorial can be downloaded from [Google Drive](https://drive.google.com/drive/folders/1l9W0MDVZ451k1L7s6GGH4ONH4tEK4EKj). It has to be stored under ```<repository_root>/data/spatial_omics/```.
#     - starmap_plus_mouse_cns_batch1.h5ad (reference sample 1)
#     - starmap_plus_mouse_cns_batch2.h5ad (reference sample 2)
#     - starmap_plus_mouse_cns_batch3.h5ad (query sample 1)
# - A pretrained model to run only the analysis can be downloaded from [Google Drive](https://drive.google.com/drive/folders/1z2DQHV9hG22B5OSWox8U3usf_8LKZGGH). It has to be stored under ```<repository_root>/artifacts/spatial_reference_mapping/<timestamp>/model/```.
#   - ```<timestamp>```: 22082024_004645

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import random
import warnings
from datetime import datetime

import anndata as ad
import gdown
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sp
import seaborn as sns
import squidpy as sq
from matplotlib import gridspec
from sklearn.preprocessing import MinMaxScaler

from nichecompass.models import NicheCompass
from nichecompass.utils import (add_gps_from_gp_dict_to_adata,
                                create_new_color_dict,
                                compute_communication_gp_network,
                                visualize_communication_gp_network,
                                extract_gp_dict_from_mebocost_ms_interactions,
                                extract_gp_dict_from_nichenet_lrt_interactions,
                                extract_gp_dict_from_omnipath_lr_interactions,
                                filter_and_combine_gp_dict_gps_v2,
                                generate_enriched_gp_info_plots)

# %% [markdown]
# ### 1.2 Define Parameters

# %%
### Dataset ###
dataset = "starmap_plus_mouse_cns"
species = "mouse"
reference_batches = ["batch1", "batch2"]
query_batches = ["batch3"]
spatial_key = "spatial"
n_neighbors = 4
mapping_entity_key = "mapping_entity"

### Model ###
# AnnData keys
counts_key = "counts"
adj_key = "spatial_connectivities"
cat_covariates_keys = ["batch"]
gp_names_key = "nichecompass_gp_names"
active_gp_names_key = "nichecompass_active_gp_names"
gp_targets_mask_key = "nichecompass_gp_targets"
gp_targets_categories_mask_key = "nichecompass_gp_targets_categories"
gp_sources_mask_key = "nichecompass_gp_sources"
gp_sources_categories_mask_key = "nichecompass_gp_sources_categories"
latent_key = "nichecompass_latent"

# Architecture
cat_covariates_embeds_injection = ["gene_expr_decoder"]
cat_covariates_embeds_nums = [3]
cat_covariates_no_edges = [True]
conv_layer_encoder = "gcnconv" # change to "gatv2conv" if enough compute and memory
active_gp_thresh_ratio = 0.01

# Trainer
n_epochs = 400
n_epochs_all_gps = 25
lr = 0.001
lambda_edge_recon = 500000.
lambda_gene_expr_recon = 300.
lambda_l1_masked = 0. # prior GP  regularization
lambda_l1_addon = 30. # de novo GP regularization
edge_batch_size = 4096 # increase if more memory available or decrease to save memoryle
n_sampled_neighbors = 4
use_cuda_if_available = True

### Analysis ###
cell_type_key = "Main_molecular_cell_type"
latent_leiden_resolution = 0.3
latent_cluster_key = f"latent_leiden_{str(latent_leiden_resolution)}"
sample_key = "batch"
spot_size = 0.2
differential_gp_test_results_key = "nichecompass_differential_gp_test_results"

# %% [markdown]
# ### 1.3 Run Notebook Setup

# %%
warnings.filterwarnings("ignore")

# %%
# Get time of notebook execution for timestamping saved artifacts
now = datetime.now()
current_timestamp = now.strftime("%d%m%Y_%H%M%S")

# %% [markdown]
# ### 1.4 Configure Paths

# %%
# Define paths
ga_data_folder_path = "../../../data/gene_annotations"
gp_data_folder_path = "../../../data/gene_programs"
so_data_folder_path = "../../../data/spatial_omics"
omnipath_lr_network_file_path = f"{gp_data_folder_path}/omnipath_lr_network.csv"
nichenet_lr_network_file_path = f"{gp_data_folder_path}/nichenet_lr_network_v2_{species}.csv"
nichenet_ligand_target_matrix_file_path = f"{gp_data_folder_path}/nichenet_ligand_target_matrix_v2_{species}.csv"
mebocost_enzyme_sensor_interactions_folder_path = f"{gp_data_folder_path}/metabolite_enzyme_sensor_gps"
gene_orthologs_mapping_file_path = f"{ga_data_folder_path}/human_mouse_gene_orthologs.csv"
artifacts_folder_path = f"../../../artifacts"
model_folder_path = f"{artifacts_folder_path}/spatial_reference_mapping/{current_timestamp}/model"
figure_folder_path = f"{artifacts_folder_path}/spatial_reference_mapping/{current_timestamp}/figures"

# %% [markdown]
# ### 1.5 Create Directories

# %%
os.makedirs(model_folder_path, exist_ok=True)
os.makedirs(figure_folder_path, exist_ok=True)
os.makedirs(so_data_folder_path, exist_ok=True)

# %% [markdown]
# ### 1.6 Download Files (Optional)
# You can skip this part if you have downloaded the files mentioned above manually, or you are using your own data.

# %%
gdown.download("https://drive.google.com/uc?id=1MOjIyue7a-JDAcnAseqIljDyoO7KtH99", so_data_folder_path+"/starmap_plus_mouse_cns_batch1.h5ad")
gdown.download("https://drive.google.com/uc?id=1_RcLVuZcJiFw-iaB7saPX4ydR1X2CvaS", so_data_folder_path+"/starmap_plus_mouse_cns_batch2.h5ad")
gdown.download("https://drive.google.com/uc?id=1sIIHGZ55aYBbgCXCBvIrGxB7i7OgUuJ9", so_data_folder_path+"/starmap_plus_mouse_cns_batch3.h5ad")

# %% [markdown]
# ## 2. Prepare Reference Model Training

# %% [markdown]
# ### 2.1 Create Prior Knowledge Gene Program (GP) Mask

# %% [markdown]
# - NicheCompass expects a prior GP mask as input, which it will use to make its latent feature space interpretable (through linear masked decoders).
# - The user can provide a custom GP mask to NicheCompass based on the biological question of interest.
# - As a default, here we create a GP mask based on three databases of prior knowledge of inter- and intracellular interaction pathways:
#     - OmniPath (Ligand-Receptor GPs)
#     - MEBOCOST (Enzyme-Sensor GPs)
#     - NicheNet (Combined Interaction GPs)

# %%
# Retrieve OmniPath GPs (source: ligand genes; target: receptor genes)
omnipath_gp_dict = extract_gp_dict_from_omnipath_lr_interactions(
    species=species,
    load_from_disk=False,
    save_to_disk=True,
    lr_network_file_path=omnipath_lr_network_file_path,
    gene_orthologs_mapping_file_path=gene_orthologs_mapping_file_path,
    plot_gp_gene_count_distributions=True,
    gp_gene_count_distributions_save_path=f"{figure_folder_path}" \
                                           "/omnipath_gp_gene_count_distributions.svg")

# %%
# Display example OmniPath GP
omnipath_gp_names = list(omnipath_gp_dict.keys())
random.shuffle(omnipath_gp_names)
omnipath_gp_name = omnipath_gp_names[0]
print(f"{omnipath_gp_name}: {omnipath_gp_dict[omnipath_gp_name]}")

# %%
# Retrieve NicheNet GPs (source: ligand genes; target: receptor genes, target genes)
nichenet_gp_dict = extract_gp_dict_from_nichenet_lrt_interactions(
    species=species,
    version="v2",
    keep_target_genes_ratio=1.,
    max_n_target_genes_per_gp=250,
    load_from_disk=False,
    save_to_disk=True,
    lr_network_file_path=nichenet_lr_network_file_path,
    ligand_target_matrix_file_path=nichenet_ligand_target_matrix_file_path,
    gene_orthologs_mapping_file_path=gene_orthologs_mapping_file_path,
    plot_gp_gene_count_distributions=True)

# %%
# Display example NicheNet GP
nichenet_gp_names = list(nichenet_gp_dict.keys())
random.shuffle(nichenet_gp_names)
nichenet_gp_name = nichenet_gp_names[0]
print(f"{nichenet_gp_name}: {nichenet_gp_dict[nichenet_gp_name]}")

# %%
# Retrieve MEBOCOST GPs (source: enzyme genes; target: sensor genes)
mebocost_gp_dict = extract_gp_dict_from_mebocost_ms_interactions(
    dir_path=mebocost_enzyme_sensor_interactions_folder_path,
    species=species,
    plot_gp_gene_count_distributions=True)

# %%
# Display example MEBOCOST GP
mebocost_gp_names = list(mebocost_gp_dict.keys())
random.shuffle(mebocost_gp_names)
mebocost_gp_name = mebocost_gp_names[0]
print(f"{mebocost_gp_name}: {mebocost_gp_dict[mebocost_gp_name]}")

# %%
# Filter and combine GPs
gp_dicts = [omnipath_gp_dict, nichenet_gp_dict, mebocost_gp_dict]
combined_gp_dict = filter_and_combine_gp_dict_gps_v2(
    gp_dicts,
    verbose=True)

print(f"Number of gene programs after filtering and combining: "
      f"{len(combined_gp_dict)}.")

# %% [markdown]
# ### 2.2 Load Reference Data & Compute Spatial Neighbor Graph

# %% [markdown]
# - NicheCompass expects a precomputed spatial adjacency matrix stored in 'adata.obsp[adj_key]'.
# - The user can customize the spatial neighbor graph construction based on the biological question of interest.
# - In the spatial reference mapping setting, we will compute a separate spatial adjacency matrix for each sample in the reference and query, respectively, and combine them as two disconnected components, one for the reference and one for the query. Here, we build the dataset used for reference model training.

# %%
adata_batch_list = []
print("Processing reference batches...")
for batch in reference_batches:
    print(f"Processing batch {batch}...")
    print("Loading data...")
    adata_batch = sc.read_h5ad(
        f"{so_data_folder_path}/{dataset}_{batch}.h5ad")

    print("Computing spatial neighborhood graph...\n")
    # Compute (separate) spatial neighborhood graphs
    sq.gr.spatial_neighbors(adata_batch,
                            coord_type="generic",
                            spatial_key=spatial_key,
                            n_neighs=n_neighbors)
    
    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
adata_reference = ad.concat(adata_batch_list, join="inner")

# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_reference.obsp[adj_key] = sp.vstack(batch_connectivities)

adata_reference.obs[mapping_entity_key] = "reference"

# %% [markdown]
# ### 2.3 Add GP Mask to Reference Data

# %%
# Add the GP dictionary as binary masks to the adata
add_gps_from_gp_dict_to_adata(
    gp_dict=combined_gp_dict,
    adata=adata_reference,
    gp_targets_mask_key=gp_targets_mask_key,
    gp_targets_categories_mask_key=gp_targets_categories_mask_key,
    gp_sources_mask_key=gp_sources_mask_key,
    gp_sources_categories_mask_key=gp_sources_categories_mask_key,
    gp_names_key=gp_names_key,
    min_genes_per_gp=2,
    min_source_genes_per_gp=1,
    min_target_genes_per_gp=1,
    max_genes_per_gp=None,
    max_source_genes_per_gp=None,
    max_target_genes_per_gp=None)

# %% [markdown]
# ### 2.4 Explore Data

# %%
cell_type_colors = create_new_color_dict(
    adata=adata_reference,
    cat_key=cell_type_key)

# %%
samples_reference = adata_reference.obs[sample_key].unique().tolist()

# %%
for sample in samples_reference:
    adata_batch = adata_reference[adata_reference.obs[sample_key] == sample]
    
    print(f"Summary of sample {sample}:")
    print(f"Number of nodes (observations): {adata_batch.layers[counts_key].shape[0]}")
    print(f"Number of node features (genes): {adata_batch.layers[counts_key].shape[1]}")

    # Visualize cell-level annotated data in physical space
    sc.pl.spatial(adata_batch,
                  color=cell_type_key,
                  palette=cell_type_colors,
                  spot_size=spot_size)

# %% [markdown]
# ## 3. Train Reference Model

# %% [markdown]
# ### 3.1 Initialize, Train & Save Model

# %%
# Initialize model
model = NicheCompass(adata_reference,
                     counts_key=counts_key,
                     adj_key=adj_key,
                     cat_covariates_embeds_injection=cat_covariates_embeds_injection,
                     cat_covariates_keys=cat_covariates_keys,
                     cat_covariates_no_edges=cat_covariates_no_edges,
                     cat_covariates_embeds_nums=cat_covariates_embeds_nums,
                     gp_names_key=gp_names_key,
                     active_gp_names_key=active_gp_names_key,
                     gp_targets_mask_key=gp_targets_mask_key,
                     gp_targets_categories_mask_key=gp_targets_categories_mask_key,
                     gp_sources_mask_key=gp_sources_mask_key,
                     gp_sources_categories_mask_key=gp_sources_categories_mask_key,
                     latent_key=latent_key,
                     conv_layer_encoder=conv_layer_encoder,
                     active_gp_thresh_ratio=active_gp_thresh_ratio)

# %%
# Train model
model.train(n_epochs=n_epochs,
            n_epochs_all_gps=n_epochs_all_gps,
            lr=lr,
            lambda_edge_recon=lambda_edge_recon,
            lambda_gene_expr_recon=lambda_gene_expr_recon,
            lambda_l1_masked=lambda_l1_masked,
            edge_batch_size=edge_batch_size,
            n_sampled_neighbors=n_sampled_neighbors,
            use_cuda_if_available=use_cuda_if_available,
            verbose=False)

# %%
# Compute latent neighbor graph
sc.pp.neighbors(model.adata,
                use_rep=latent_key,
                key_added=latent_key)

# Compute UMAP embedding
sc.tl.umap(model.adata,
           neighbors_key=latent_key)

# %%
# Save trained model
model.save(dir_path=f"{model_folder_path}/reference",
           overwrite=True,
           save_adata=True,
           adata_file_name="adata.h5ad")

# %% [markdown]
# ## 4. Prepare Query Mapping

# %% [markdown]
# ### 4.1 Load Query Data & Compute Spatial Neighbor Graph

# %% [markdown]
# Now we will load the query samples to fine-tune the reference model.

# %%
adata_batch_list = []
print("Processing query batches...")
for batch in query_batches:
    print(f"Processing batch {batch}...")
    print("Loading data...")
    adata_batch = sc.read_h5ad(
        f"{so_data_folder_path}/{dataset}_{batch}.h5ad")

    print("Computing spatial neighborhood graph...\n")
    # Compute (separate) spatial neighborhood graphs
    sq.gr.spatial_neighbors(adata_batch,
                            coord_type="generic",
                            spatial_key=spatial_key,
                            n_neighs=n_neighbors)
    
    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
adata_query = ad.concat(adata_batch_list, join="inner")

# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_query.obsp[adj_key] = sp.vstack(batch_connectivities)

adata_query.obs[mapping_entity_key] = "query"

# %% [markdown]
# ### 4.2 Add GP Mask to Query Data

# %%
# Add the GP dictionary as binary masks to the adata
add_gps_from_gp_dict_to_adata(
    gp_dict=combined_gp_dict,
    adata=adata_query,
    gp_targets_mask_key=gp_targets_mask_key,
    gp_targets_categories_mask_key=gp_targets_categories_mask_key,
    gp_sources_mask_key=gp_sources_mask_key,
    gp_sources_categories_mask_key=gp_sources_categories_mask_key,
    gp_names_key=gp_names_key,
    min_genes_per_gp=2,
    min_source_genes_per_gp=1,
    min_target_genes_per_gp=1,
    max_genes_per_gp=None,
    max_source_genes_per_gp=None,
    max_target_genes_per_gp=None)

# %% [markdown]
# ### 4.3 Explore Data

# %%
cell_type_colors = create_new_color_dict(
    adata=adata_query,
    cat_key=cell_type_key)

# %%
samples_query = adata_query.obs[sample_key].unique().tolist()

# %%
for sample in samples_query:
    adata_batch = adata_query[adata_query.obs[sample_key] == sample]
    
    print(f"Summary of sample {sample}:")
    print(f"Number of nodes (observations): {adata_batch.layers[counts_key].shape[0]}")
    print(f"Number of node features (genes): {adata_batch.layers[counts_key].shape[1]}")

    # Visualize cell-level annotated data in physical space
    sc.pl.spatial(adata_batch,
                  color=cell_type_key,
                  palette=cell_type_colors,
                  spot_size=spot_size)

# %% [markdown]
# ## 5. Map Query onto Reference Model

# %% [markdown]
# ### 5.1 Initialize, Train & Save Model

# %% [markdown]
# Load model trained on reference data for transfer learning with query data. Freeze all weights except for covariate embedding weights.

# %%
load_timestamp = "22082024_004645"
# load_timestamp = current_timestamp # uncomment if you trained the model in this notebook

model_folder_path = f"{artifacts_folder_path}/spatial_reference_mapping/{load_timestamp}/model"

# %% [markdown]
# **What adapts during mapping, and what does not**
#
# `load()` freezes every parameter and unfreezes only the groups you ask for.
# The gene program loadings are never in those groups unless you pass
# `unfreeze_all_weights`, which is what keeps a GP score comparable between
# reference and query and lets the reference orientation signs carry forward.
#
# The choice that matters is **what is allowed to move the latent**:
#
# | | what it adapts | works on an existing reference |
# | --- | --- | --- |
# | `unfreeze_cat_covariates_embedder_weights` | a per-batch embedding, which reaches the latent only if the reference was trained with `"encoder"` in `cat_covariates_embeds_injection` (now the default) | only if it was |
# | `n_graph_adapter_hidden` + `unfreeze_graph_adapters` | a residual bottleneck with its own message passing, so it responds to neighbourhood composition; identity at initialisation | yes |
# | `unfreeze_encoder_weights` | the whole encoder — most capacity, no anchor to the reference | yes |
#
# `load()` warns if nothing you unfroze can reach the latent at all. That was
# the situation this tutorial used to be in: with a decoder-only reference and
# only the covariate embedder unfrozen, 400 epochs fit a reconstruction offset
# downstream of the latent and changed no gene program score.
#
# Freezing also protects the repertoire: programs whose loadings are frozen hold
# their activity statistic and are never pruned, so a reference program quiet in
# the query tissue is reported inactive rather than deleted from the checkpoint.
# See the [reference mapping guide](../../user_guide/reference_mapping.md).
#
# We record reference GP identities and signs before fine-tuning, then compare
# them afterwards. Preserved signs do not imply identical activities. Matching
# prior GP IDs across independent fits also does not establish comparable latent
# activity scales.

# %%
# Loading reference model with query data.
# ´load´ prints which parameters it unfroze, and warns if none of them can
# reach the latent.
print("Retrieving reference model...")
model = NicheCompass.load(
    dir_path=f"{model_folder_path}/reference",
    adata=adata_query,
    adata_file_name="adata.h5ad",
    gp_names_key=gp_names_key,
    unfreeze_all_weights=False,
    unfreeze_cat_covariates_embedder_weights=True,
    # Bounded, retrofittable adaptation of the query neighbourhoods. Comment
    # these two out to reproduce the covariate-only mapping, or swap them for
    # ´unfreeze_encoder_weights=True´ for an unanchored full-encoder fit.
    n_graph_adapter_hidden=32,
    unfreeze_graph_adapters=True)
print(f"Adapting {len(model.unfrozen_parameter_names_)} tensors; "
      f"gene program loadings frozen: {model.freeze_}")

model.prepare_gp_analysis()
model.add_active_gp_scores_to_obs()

# The latent BEFORE any fine-tuning, to measure what the mapping changed.
# ´train´ is what normally populates ´obsm[latent_key]´, so it has to be
# computed explicitly here. The adapter is the identity at initialisation, so
# this is exactly the frozen reference model's view of the query data.
print("Computing the pre-mapping query latent GP space...")
latent_before_mapping, _ = model.get_latent_representation(
    adata=model.adata,
    counts_key=counts_key,
    adj_key=adj_key,
    cat_covariates_keys=cat_covariates_keys,
    only_active_gps=True,
    return_mu_std=True,
    node_batch_size=model.node_batch_size_)

# %%
reference_orientation = model.get_gp_quality_table()[
    ["gp_id", "gp_name", "orientation_sign"]].rename(
        columns={"orientation_sign": "reference_sign"})

# %%
# Train model
model.train(n_epochs=n_epochs,
            n_epochs_all_gps=n_epochs_all_gps,
            lr=lr,
            lambda_edge_recon=lambda_edge_recon,
            lambda_gene_expr_recon=lambda_gene_expr_recon,
            lambda_l1_masked=lambda_l1_masked,
            edge_batch_size=edge_batch_size,
            n_sampled_neighbors=n_sampled_neighbors,
            use_cuda_if_available=use_cuda_if_available)

# %%
mapped_quality = model.get_gp_quality_table()
orientation_check = reference_orientation.merge(
    mapped_quality[["gp_id", "orientation_sign", "orientation_status", "coherence"]],
    on="gp_id", validate="one_to_one")
assert len(orientation_check) == len(reference_orientation)
assert (orientation_check["reference_sign"] == orientation_check["orientation_sign"]).all()
display(orientation_check.head(10))

# %% [markdown]
# **Did the mapping change anything?**
#
# Worth checking explicitly rather than assuming. `latent_before_mapping` is the
# reference model's view of the query data, captured before training — the
# adapter is the identity at initialisation, so it is exactly what a frozen
# reference would produce. Comparing against the latent after fine-tuning says
# how much the adaptation actually moved, and the per-programme correlation says
# whether the programmes still mean the same thing.
#
# If the shift is ~0 and every correlation is 1.0, nothing that was unfrozen
# could reach the latent, and the run was a no-op for every quantity you go on
# to interpret.

# %%
# Latent after fine-tuning, on the same cells. ´train´ populated
# ´obsm[latent_key]´, so read it from there.
model.add_active_gp_scores_to_obs()
latent_after_mapping = model.adata.obsm[latent_key]

shift = np.linalg.norm(latent_after_mapping - latent_before_mapping, axis=1)
scale = np.linalg.norm(latent_before_mapping, axis=1).mean()
print(f"Per-cell latent shift: mean {shift.mean():.4f}, max {shift.max():.4f}")
print(f"  relative to the mean latent norm ({scale:.4f}): "
      f"{100 * shift.mean() / scale:.2f}%")
if shift.mean() < 1e-6:
    print("  -> the mapping did not move the latent at all")

# Per-programme: did activities stay comparable, and which moved most?
active_gps = model.get_active_gps()
gp_shift = pd.DataFrame({
    "gene_program": active_gps,
    "correlation": [
        np.corrcoef(latent_before_mapping[:, i],
                    latent_after_mapping[:, i])[0, 1]
        for i in range(len(active_gps))],
    "mean_abs_change": np.abs(
        latent_after_mapping - latent_before_mapping).mean(0)[:len(active_gps)],
}).sort_values("mean_abs_change", ascending=False)

print(f"\nProgrammes with correlation < 0.99 before/after: "
      f"{(gp_shift['correlation'] < 0.99).sum()} of {len(gp_shift)}")
gp_shift.head(10)

# %%
# Save trained model
model.save(dir_path=f"{model_folder_path}/query",
           overwrite=True,
           save_adata=True,
           adata_file_name="adata.h5ad")

# %% [markdown]
# ### 5.2 Integrate Reference & Query Data

# %% [markdown]
# Now that we have fine-tuned the reference model with the query data, we will load it with the integrated reference and query data.

# %%
# Integrate reference and query data
adata_batch_list = [adata_reference, adata_query]
adata_reference_query = ad.concat(adata_batch_list, join="inner")

# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_reference_query.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference_query.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference_query.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_reference_query.obsp[adj_key] = sp.vstack(batch_connectivities)

# %% [markdown]
# ### 5.3 Add GP Mask to Integrated Data

# %%
# Add the GP dictionary as binary masks to the adata
add_gps_from_gp_dict_to_adata(
    gp_dict=combined_gp_dict,
    adata=adata_reference_query,
    gp_targets_mask_key=gp_targets_mask_key,
    gp_targets_categories_mask_key=gp_targets_categories_mask_key,
    gp_sources_mask_key=gp_sources_mask_key,
    gp_sources_categories_mask_key=gp_sources_categories_mask_key,
    gp_names_key=gp_names_key,
    min_genes_per_gp=2,
    min_source_genes_per_gp=1,
    min_target_genes_per_gp=1,
    max_genes_per_gp=None,
    max_source_genes_per_gp=None,
    max_target_genes_per_gp=None)

# %% [markdown]
# ### 5.4 Load Fine-tuned Model with Reference & Query Data

# %%
# Load query model with the integrated data
print("Retrieving query model...")
model = NicheCompass.load(
    dir_path=f"{model_folder_path}/query",
    adata=adata_reference_query,
    adata_file_name="adata.h5ad",
    gp_names_key=gp_names_key)
model.prepare_gp_analysis()
model.add_active_gp_scores_to_obs()

# %%
print("Computing reference query latent GP space...")
model.adata.obsm[latent_key], _ = model.get_latent_representation(
   adata=model.adata,
   counts_key=counts_key,
   adj_key=adj_key,
   cat_covariates_keys=cat_covariates_keys,
   only_active_gps=True,
   return_mu_std=True,
   node_batch_size=model.node_batch_size_)

print("Computing active GPs...")
model.adata.uns[model.active_gp_names_key_] = model.get_active_gps()

# %%
# Compute latent neighbor graph
sc.pp.neighbors(model.adata,
                use_rep=latent_key,
                key_added=latent_key)

# Compute UMAP embedding
sc.tl.umap(model.adata,
           neighbors_key=latent_key)

# %% [markdown]
# **Reference against query, programme by programme**
#
# Now that both datasets share one model, the comparison that matters is whether
# a programme behaves the same way in the reference and in the query. Two
# distinct questions, and they need different answers:
#
# - **Are the programmes comparable?** The loadings are frozen and the signs are
#   inherited, so a programme's axis is identical in both. Its *activity
#   distribution* can still differ, and should, where the biology differs.
# - **Is the shift biological or technical?** A programme whose activity is
#   uniformly offset between the two datasets, with the same spatial pattern
#   within each, is more likely a residual batch effect than a finding. One
#   whose spatial pattern differs is the interesting case.
#
# The test below is deliberately weak: it compares distributions per programme
# and ranks by separation. It does **not** provide donor-level inference or FDR
# control, and a large separation on one reference and one query section is one
# observation, not a result.

# %%
# Per-programme activity in reference versus query
is_query = (model.adata.obs[mapping_entity_key] == "query").to_numpy()
active_gps = model.get_active_gps()
activities = model.get_gp_activities(active_gps)

comparison = pd.DataFrame({
    "gene_program": active_gps,
    "reference_mean": activities[~is_query].mean(0),
    "query_mean": activities[is_query].mean(0),
    "reference_sd": activities[~is_query].std(0),
    "query_sd": activities[is_query].std(0)})
comparison["difference"] = (comparison["query_mean"]
                            - comparison["reference_mean"])
# Standardised separation, pooling the two spreads. A crude effect size, used
# only to order the programmes for inspection.
pooled = np.sqrt((comparison["reference_sd"] ** 2
                  + comparison["query_sd"] ** 2) / 2).replace(0, np.nan)
comparison["separation"] = comparison["difference"] / pooled
comparison = comparison.sort_values(
    "separation", key=np.abs, ascending=False).reset_index(drop=True)

print(f"{is_query.sum()} query cells, {(~is_query).sum()} reference cells")
print(f"Median |separation| across programmes: "
      f"{comparison['separation'].abs().median():.3f}")
comparison.head(10)

# %%
# Reference versus query mean activity, one point per programme.
# Points on the diagonal behave the same way in both datasets.
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(13, 5.5))

lim = np.abs(np.concatenate([comparison["reference_mean"],
                             comparison["query_mean"]])).max() * 1.1
axs[0].axline((0, 0), slope=1, color="lightgrey", zorder=0)
axs[0].axhline(0, color="lightgrey", lw=0.8, zorder=0)
axs[0].axvline(0, color="lightgrey", lw=0.8, zorder=0)
axs[0].scatter(comparison["reference_mean"], comparison["query_mean"],
               s=22, alpha=0.75)
for _, row in comparison.head(5).iterrows():
    axs[0].annotate(row["gene_program"].replace("_combined_GP", ""),
                    (row["reference_mean"], row["query_mean"]),
                    fontsize=7, xytext=(4, 4), textcoords="offset points")
axs[0].set(xlabel="Reference mean activity", ylabel="Query mean activity",
           xlim=(-lim, lim), ylim=(-lim, lim),
           title="Programme activity, reference vs query")

axs[1].hist(comparison["separation"].dropna(), bins=30)
axs[1].axvline(0, color="black", lw=0.8)
axs[1].set(xlabel="Standardised difference (query - reference)",
           ylabel="Gene programmes",
           title="Distribution of separation")
plt.tight_layout()
plt.show()

# %%
# Save model
model.save(dir_path=f"{model_folder_path}/reference_query",
           overwrite=True,
           save_adata=True,
           adata_file_name="adata.h5ad")

# %% [markdown]
# ## 6. Analysis

# %%
load_timestamp = "22082024_004645"

figure_folder_path = f"{artifacts_folder_path}/spatial_reference_mapping/{load_timestamp}/figures"
model_folder_path = f"{artifacts_folder_path}/spatial_reference_mapping/{load_timestamp}/model" \
                     "/reference_query"

os.makedirs(figure_folder_path, exist_ok=True)

# %%
# Load trained model
model = NicheCompass.load(dir_path=model_folder_path,
                          adata=None,
                          adata_file_name="adata.h5ad",
                          gp_names_key=gp_names_key)

# %% [markdown]
# **Prepare a consistent GP analysis view**
#
# A GP activity and its decoder loadings can change sign together while preserving
# their product. NicheCompass resolves this ambiguity for interpretation with the
# `paper_2025` convention: a prior GP uses the sum of its source RNA loadings,
# falling back to targets only if it has no measured source members. Add-on GPs use
# both RNA blocks. A negative sum gives a sign of −1; a zero or positive sum gives +1.
#
# The same sign multiplies activity means and all source/target RNA/ATAC loadings.
# Posterior standard deviations, model parameters, reconstruction and latent-space
# geometry stay unchanged. Do not flip individual score columns or test statistics.
#
# New training runs initialize this convention automatically. The explicit call below
# also opts a historical checkpoint into canonical analysis; repeating it is safe
# while the decoder is unchanged. Refreshing score columns replaces old/manual scores.
# Raw access is still available with `orientation="raw"`; the low-level
# `get_latent_representation()` remains raw by default.

# %%
model.prepare_gp_analysis()
model.add_active_gp_scores_to_obs()

# %%
samples = model.adata.obs[sample_key].unique().tolist()

# %% [markdown]
# ### 6.1 Visualize NicheCompass Latent GP Space

# %% [markdown]
# First, we will check how well the NicheCompass latent GP features are integrated across reference and query.

# %%
mapping_entity_colors = create_new_color_dict(
    adata=model.adata,
    cat_key=mapping_entity_key)

# %%
# Create plot of mapping entity annotations in physical and latent space
groups = None
save_fig = True
file_path = f"{figure_folder_path}/" \
            "batches_latent_physical_space.svg"

fig = plt.figure(figsize=(12, 14))
title = fig.suptitle(t=f"NicheCompass Batches " \
                       "in Latent and Physical Space",
                     y=0.96,
                     x=0.55,
                     fontsize=20)
spec1 = gridspec.GridSpec(ncols=1,
                          nrows=2,
                          width_ratios=[1],
                          height_ratios=[3, 2])
spec2 = gridspec.GridSpec(ncols=len(samples),
                          nrows=2,
                          width_ratios=[1] * len(samples),
                          height_ratios=[3, 2])
axs = []
axs.append(fig.add_subplot(spec1[0]))
sc.pl.umap(adata=model.adata,
           color=[mapping_entity_key],
           groups=groups,
           palette=mapping_entity_colors,
           title=f"Batches in Latent Space",
           ax=axs[0],
           show=False)
for idx, sample in enumerate(samples):
    axs.append(fig.add_subplot(spec2[len(samples) + idx]))
    sc.pl.spatial(adata=model.adata[model.adata.obs[sample_key] == sample],
                  color=[mapping_entity_key],
                  groups=groups,
                  palette=mapping_entity_colors,
                  spot_size=spot_size,
                  title=f"Batches in Physical Space \n"
                        f"(Sample: {sample})",
                  legend_loc=None,
                  ax=axs[idx+1],
                  show=False)

# Create and position shared legend
handles, labels = axs[0].get_legend_handles_labels()
lgd = fig.legend(handles,
                 labels,
                 loc="center left",
                 bbox_to_anchor=(0.98, 0.5))
axs[0].get_legend().remove()

# Adjust, save and display plot
plt.subplots_adjust(wspace=0.2, hspace=0.25)
if save_fig:
    fig.savefig(file_path,
                bbox_extra_artists=(lgd, title),
                bbox_inches="tight")
plt.show()

# %% [markdown]
# Next, we will check how well the NicheCompass latent GP features are integrated across different batches.

# %%
batch_colors = create_new_color_dict(
    adata=model.adata,
    cat_key=cat_covariates_keys[0])

# %%
# Create plot of batch annotations in physical and latent space
groups = None
save_fig = True
file_path = f"{figure_folder_path}/" \
            "batches_latent_physical_space.svg"

fig = plt.figure(figsize=(12, 14))
title = fig.suptitle(t=f"NicheCompass Batches " \
                       "in Latent and Physical Space",
                     y=0.96,
                     x=0.55,
                     fontsize=20)
spec1 = gridspec.GridSpec(ncols=1,
                          nrows=2,
                          width_ratios=[1],
                          height_ratios=[3, 2])
spec2 = gridspec.GridSpec(ncols=len(samples),
                          nrows=2,
                          width_ratios=[1] * len(samples),
                          height_ratios=[3, 2])
axs = []
axs.append(fig.add_subplot(spec1[0]))
sc.pl.umap(adata=model.adata,
           color=[cat_covariates_keys[0]],
           groups=groups,
           palette=batch_colors,
           title=f"Batches in Latent Space",
           ax=axs[0],
           show=False)
for idx, sample in enumerate(samples):
    axs.append(fig.add_subplot(spec2[len(samples) + idx]))
    sc.pl.spatial(adata=model.adata[model.adata.obs[sample_key] == sample],
                  color=[cat_covariates_keys[0]],
                  groups=groups,
                  palette=batch_colors,
                  spot_size=spot_size,
                  title=f"Batches in Physical Space \n"
                        f"(Sample: {sample})",
                  legend_loc=None,
                  ax=axs[idx+1],
                  show=False)

# Create and position shared legend
handles, labels = axs[0].get_legend_handles_labels()
lgd = fig.legend(handles,
                 labels,
                 loc="center left",
                 bbox_to_anchor=(0.98, 0.5))
axs[0].get_legend().remove()

# Adjust, save and display plot
plt.subplots_adjust(wspace=0.2, hspace=0.25)
if save_fig:
    fig.savefig(file_path,
                bbox_extra_artists=(lgd, title),
                bbox_inches="tight")
plt.show()

# %% [markdown]
# Next, let's look at the preservation of cell type annotations in the latent GP space. Note that the goal of NicheCompass is not a separation of cell types but rather to identify spatially consistent cell niches.

# %%
cell_type_colors = create_new_color_dict(
    adata=model.adata,
    cat_key=cell_type_key)

# %%
# Create plot of cell type annotations in physical and latent space
groups = None
save_fig = True
file_path = f"{figure_folder_path}/" \
            "cell_types_latent_physical_space.svg"

fig = plt.figure(figsize=(12, 14))
title = fig.suptitle(t=f"Cell Types " \
                       "in Latent and Physical Space",
                     y=0.96,
                     x=0.55,
                     fontsize=20)
spec1 = gridspec.GridSpec(ncols=1,
                          nrows=2,
                          width_ratios=[1],
                          height_ratios=[3, 2])
spec2 = gridspec.GridSpec(ncols=len(samples),
                          nrows=2,
                          width_ratios=[1] * len(samples),
                          height_ratios=[3, 2])
axs = []
axs.append(fig.add_subplot(spec1[0]))
sc.pl.umap(adata=model.adata,
           color=[cell_type_key],
           groups=groups,palette=cell_type_colors,
           title=f"Cell Types in Latent Space",
           ax=axs[0],
           show=False)
for idx, sample in enumerate(samples):
    axs.append(fig.add_subplot(spec2[len(samples) + idx]))
    sc.pl.spatial(adata=model.adata[model.adata.obs[sample_key] == sample],
                  color=[cell_type_key],
                  groups=groups,
                  palette=cell_type_colors,
                  spot_size=spot_size,
                  title=f"Cell Types in Physical Space \n"
                        f"(Sample: {sample})",
                  legend_loc=None,
                  ax=axs[idx+1],
                  show=False)

# Create and position shared legend
handles, labels = axs[0].get_legend_handles_labels()
lgd = fig.legend(handles,
                 labels,
                 loc="center left",
                 bbox_to_anchor=(0.98, 0.5))
axs[0].get_legend().remove()

# Adjust, save and display plot
plt.subplots_adjust(wspace=0.2, hspace=0.25)
if save_fig:
    fig.savefig(file_path,
                bbox_extra_artists=(lgd, title),
                bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 6.2 Identify Niches

# %% [markdown]
# We compute Leiden clustering based on the NicheCompass embeddings to identify spatial cellular niches.

# %%
# Compute latent Leiden clustering
sc.tl.leiden(adata=model.adata,
             resolution=latent_leiden_resolution,
             key_added=latent_cluster_key,
             neighbors_key=latent_key)

# %%
latent_cluster_colors = create_new_color_dict(
    adata=model.adata,
    cat_key=latent_cluster_key)

# %%
# Create plot of latent cluster / niche annotations in physical and latent space
groups = None # set this to a specific cluster for easy visualization, e.g. ["0"]
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"res_{latent_leiden_resolution}_" \
            "niches_latent_physical_space.svg"

fig = plt.figure(figsize=(12, 14))
title = fig.suptitle(t=f"NicheCompass Niches " \
                       "in Latent and Physical Space",
                     y=0.96,
                     x=0.55,
                     fontsize=20)
spec1 = gridspec.GridSpec(ncols=1,
                          nrows=2,
                          width_ratios=[1],
                          height_ratios=[3, 2])
spec2 = gridspec.GridSpec(ncols=len(samples),
                          nrows=2,
                          width_ratios=[1] * len(samples),
                          height_ratios=[3, 2])
axs = []
axs.append(fig.add_subplot(spec1[0]))
sc.pl.umap(adata=model.adata,
           color=[latent_cluster_key],
           groups=groups,
           palette=latent_cluster_colors,
           title=f"Niches in Latent Space",
           ax=axs[0],
           show=False)
for idx, sample in enumerate(samples):
    axs.append(fig.add_subplot(spec2[len(samples) + idx]))
    sc.pl.spatial(adata=model.adata[model.adata.obs[sample_key] == sample],
                  color=[latent_cluster_key],
                  groups=groups,
                  palette=latent_cluster_colors,
                  spot_size=spot_size,
                  title=f"Niches in Physical Space \n"
                        f"(Sample: {sample})",
                  legend_loc=None,
                  ax=axs[idx+1],
                  show=False)

# Create and position shared legend
handles, labels = axs[0].get_legend_handles_labels()
lgd = fig.legend(handles,
                 labels,
                 loc="center left",
                 bbox_to_anchor=(0.98, 0.5))
axs[0].get_legend().remove()

# Adjust, save and display plot
plt.subplots_adjust(wspace=0.2, hspace=0.25)
if save_fig:
    fig.savefig(file_path,
                bbox_extra_artists=(lgd, title),
                bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 6.3 Analyze Niches

# %% [markdown]
# Now we will analyze the identified spatial cellular niches.

# %% [markdown]
# #### 6.3.1 Niche Composition

# %% [markdown]
# We can analyze the niche composition in terms of batch and cell type labels.

# %%
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"res_{latent_leiden_resolution}_" \
            f"niche_composition_batches.svg"

df_counts = (model.adata.obs.groupby([latent_cluster_key, cat_covariates_keys[0]])
             .size().unstack())
df_counts.plot(kind="bar", stacked=True, figsize=(10,10))
legend = plt.legend(bbox_to_anchor=(1, 1), loc="upper left", prop={'size': 10})
legend.set_title("Batch Annotations", prop={'size': 10})
plt.title("Batch Composition of Niches")
plt.xlabel("Niche")
plt.ylabel("Cell Counts")
if save_fig:
    plt.savefig(file_path,
                bbox_extra_artists=(legend,),
                bbox_inches="tight")

# %%
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"res_{latent_leiden_resolution}_" \
            f"niche_composition_cell_types.svg"

df_counts = (model.adata.obs.groupby([latent_cluster_key, cell_type_key])
             .size().unstack())
df_counts.plot(kind="bar", stacked=True, figsize=(10,10))
legend = plt.legend(bbox_to_anchor=(1, 1), loc="upper left", prop={'size': 10})
legend.set_title("Cell Type Annotations", prop={'size': 10})
plt.title("Cell Type Composition of Niches")
plt.xlabel("Niche")
plt.ylabel("Cell Counts")
if save_fig:
    plt.savefig(file_path,
                bbox_extra_artists=(legend,),
                bbox_inches="tight")

# %% [markdown]
# #### 6.3.2 Interpret GP activities and members

# %% [markdown]
# **Inspect orientation quality before interpreting a direction**
#
# `get_gp_quality_table()` includes all programs and their global `gp_active` status.
# The first display orders active programs by orientation coherence so that potential
# ambiguities are easy to inspect. `anchor` identifies the RNA block used to orient a
# program; `anchor_mass` is its absolute loading mass, and `coherence` is the absolute
# signed sum divided by that mass. Low coherence means positive and negative loadings
# nearly cancel. `source_target_disagree` flags opposite aggregate directions in the
# two RNA blocks.
#
# Statuses `mixed`, `weak_support` and `zero_support` are descriptive flags, not
# calibrated confidence levels or automatic exclusion rules. Inspect the members
# before drawing a directional conclusion. The wide `get_gp_summary()` remains
# available, while the following examples use the new tidy tables. We choose the
# first active programs for an API demonstration; this ordering is not a ranking of
# biological importance.

# %%
active_gps = model.get_active_gps()
gp_quality = model.get_gp_quality_table()
gp_summary_df = model.get_gp_summary()
print(f"Active GPs: {len(active_gps)} / {len(gp_quality)}")

quality_columns = ["gp_name", "gp_type", "anchor", "orientation_sign",
                   "anchor_mass", "coherence", "orientation_status",
                   "source_target_disagree"]
display(gp_quality.loc[gp_quality["gp_active"], quality_columns]
        .sort_values("coherence").head(10))
display(gp_quality.groupby(["gp_type", "orientation_status"], observed=True)
        .size().rename("n_gps").to_frame())
if len(active_gps) == 0:
    raise ValueError("No active GPs are available; inspect the fitted model before continuing.")
example_gps = list(active_gps[:3])
example_gp = example_gps[0]

# %% [markdown]
# **Retrieve canonical activities with uncertainty**
#
# `get_gp_activities()` returns fresh posterior means with columns in exactly the
# requested GP order. `return_std=True` also returns each cell's posterior standard
# deviation; this is uncertainty in its latent activity, not a standard error across
# cells or donors. These two small previews show the same observations and programs.
# For atlas-scale data, selecting only the GPs you need limits the returned matrix size.

# %%
gp_activity, gp_std = model.get_gp_activities(example_gps, return_std=True)
activity_df = pd.DataFrame(gp_activity, index=model.adata.obs_names, columns=example_gps)
posterior_std_df = pd.DataFrame(gp_std, index=model.adata.obs_names, columns=example_gps)
display(pd.concat({"canonical_mean": activity_df.head(),
                   "posterior_std": posterior_std_df.head()}, axis=1))

# %% [markdown]
# **Read the positive and negative feature arms together**
#
# `get_gp_feature_table()` gives one row per measured source/target member, including
# zero effective loadings. `raw_loading` and `loading` show the coordinate change;
# `arm` is positive, negative or zero in the canonical view. A higher activity points
# along positive loadings and against negative ones. The signed loading acts on the
# decoder logit; it is not a gene-expression effect size, because the softmax couples
# reconstructed features.
#
# `importance` is absolute loading mass normalized across source and target together
# within each modality. It ranks members without discarding their signs; it is not
# variance explained. The table retains full precision. The bar plot shows the most
# important members of one example GP, labeled by their source/target role.

# %%
gp_features = model.get_gp_feature_table([example_gp])
feature_columns = ["gp_name", "modality", "entity", "feature", "raw_loading",
                   "loading", "arm", "importance", "orientation_sign"]
display(gp_features.sort_values("importance", ascending=False)
        .groupby(["modality", "arm"], sort=False, observed=True)
        .head(5)[feature_columns])

# %%
if gp_features.empty:
    print("This GP has no measured feature members to plot.")
else:
    modalities = gp_features["modality"].unique().tolist()
    fig, axes = plt.subplots(1, len(modalities), figsize=(7 * len(modalities), 5), squeeze=False)
    for ax, modality in zip(axes[0], modalities):
        top_members = (gp_features.loc[gp_features["modality"] == modality]
                       .nlargest(12, "importance").sort_values("loading"))
        labels = top_members["entity"] + ": " + top_members["feature"]
        colors = top_members["arm"].map({"positive": "#2878b5", "negative": "#d95f02", "zero": "gray"})
        ax.barh(labels, top_members["loading"], color=colors)
        ax.axvline(0, color="black", linewidth=0.8)
        ax.set(title=f"{example_gp} — {modality.upper()}", xlabel="Canonical decoder loading")
    fig.tight_layout()
    plt.show()

# %% [markdown]
# #### 6.3.3 Differential GP activity

# %% [markdown]
# We now compare **GP activity**, rather than testing gene expression directly.
# `selected_cats=None` tests every niche against the specified comparator
# (`"rest"` by default);
# `selected_cats=["0"]` chooses one focal niche, and `comparison_cats=["2"]`
# chooses a specific comparator. Use labels that exist in your fitted clustering.
# The string `"rest"` means all other nonmissing labels; `["rest"]` refers to a
# literal category with that name.
#
# For sampled cell pairs, the test integrates the Gaussian posterior probability
# that the focal cell has higher activity. `p_higher` and `p_lower` sum to one.
# `log_bayes_factor` is the historical column name for their log odds; the cutoff
# 2.3 corresponds to roughly 91% pairwise superiority in the selected direction.
# This is neither a donor-level condition test nor FDR control.
#
# The call below uses `direction="higher"` for the filtered enrichment table used by
# the plots, and `return_all=True` to return every tested GP/contrast in both
# directions. `n_sample` controls the number of sampled cell pairs, not the number
# of independent biological replicates. `seed` makes that sampling repeatable.

# %% [markdown]
# These comparisons pool cells across samples. Inspect the niche-by-sample
# counts below: unequal sample contributions can influence the result. Integration
# does not turn cells into independent donors, and `sample_key` in the communication
# analysis does not add replicate-aware differential testing.

# %%
display(model.adata.obs.groupby([sample_key, latent_cluster_key], observed=True)
        .size().unstack(fill_value=0))

# %%
# Set parameters for differential gp testing
selected_cats = ["19"]
comparison_cats = "rest"
title = f"NicheCompass Higher-Activity Niche GPs"
log_bayes_factor_thresh = 2.3
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"/log_bayes_factor_{log_bayes_factor_thresh}" \
             "_niches_enriched_gps_heatmap.svg"

# %%
all_gp_results = model.run_differential_gp_tests(
    cat_key=latent_cluster_key,
    selected_cats=selected_cats,
    comparison_cats=comparison_cats,
    log_bayes_factor_thresh=log_bayes_factor_thresh,
    direction="higher",
    return_all=True,
    n_sample=10000,
    seed=0,
    key_added=differential_gp_test_results_key)

enriched_results = model.adata.uns[differential_gp_test_results_key]
enriched_gps = enriched_results["gene_program"].unique().tolist()
print(f"Tested GP/contrast combinations: {len(all_gp_results)}; higher-activity GPs passing the cutoff: {len(enriched_gps)}")

# %%
result_columns = ["category", "comparison", "gene_program", "direction",
                  "p_higher", "p_lower", "log_bayes_factor", "mean_difference",
                  "n_focal", "n_comparison", "orientation_status"]
display(all_gp_results[result_columns].head(10))
display(enriched_results[result_columns].head(10))

# %% [markdown]
# The complete table is also stored under `key + "_all"`; settings and input
# fingerprints are stored under `key + "_params"`. `mean_difference` is the
# difference of group-average posterior means in latent units. It need not rank
# GPs like pairwise superiority, and is not an expression fold change.
#
# Lower activity is informative too. We can select it from the complete table
# without rerunning inference or changing the higher-activity results used by later
# plots. For a dedicated lower-activity analysis, use `direction="lower"`; use
# `direction="both"` to retain both directions in the filtered table.

# %%
lower_gp_results = all_gp_results.loc[
    (all_gp_results["direction"] == "lower")
    & (all_gp_results["log_bayes_factor"].abs() > log_bayes_factor_thresh)]
display(lower_gp_results[result_columns].head(10))
analysis_settings = model.adata.uns[differential_gp_test_results_key + "_params"]
display(pd.Series(analysis_settings, name="value").to_frame())

# %% [markdown]
# **Visualize activity patterns and export the analysis**
#
# This heatmap scales each GP's niche-average activity to [0, 1] for display.
# Colors therefore compare niches within a GP; they are not comparable effect
# sizes across programs. An empty set of hits is a valid outcome and skips the plot.

# %%
if enriched_gps:
    # Visualize GP activities of enriched GPs across niches
    df = model.adata.obs[[latent_cluster_key] + enriched_gps].groupby(latent_cluster_key).mean()

    scaler = MinMaxScaler()
    normalized_columns = scaler.fit_transform(df)
    normalized_df = pd.DataFrame(normalized_columns, columns=df.columns)
    normalized_df.index = df.index

    plt.figure(figsize=(16, 8))  # Set the figure size
    ax = sns.heatmap(normalized_df,
                cmap='viridis',
                annot=False,
                linewidths=0)
    plt.xticks(rotation=45,
               fontsize=8,
               ha="right"
              )
    plt.xlabel("Gene Programs", fontsize=16)
    plt.savefig(f"{figure_folder_path}/enriched_gps_heatmap.svg",
                bbox_inches="tight")
else:
    print('No higher-activity GPs passed the cutoff; skipping the heatmap.')

# %% [markdown]
# The exports retain all tested contrasts, higher-activity hits, quality
# diagnostics, analysis settings and signed feature members of the hits. The feature
# CSV includes zero-loading members and full-precision weights; an empty hit set
# produces an empty feature table with column headers.

# %%
# Export full-precision results and feature members of all higher-activity hits.
enriched_features = model.get_gp_feature_table(enriched_gps)
gp_quality.to_csv(f"{figure_folder_path}/gp_quality.csv", index=False)
all_gp_results.to_csv(f"{figure_folder_path}/gp_differential_all.csv", index=False)
enriched_results.to_csv(f"{figure_folder_path}/gp_differential_higher.csv", index=False)
enriched_features.to_csv(f"{figure_folder_path}/gp_enriched_features.csv", index=False)
pd.Series(analysis_settings, name="value").to_csv(f"{figure_folder_path}/gp_analysis_settings.csv")
display(enriched_features.head(10))

# %% [markdown]
# The detailed plots below refresh canonical score columns and use the same
# signed gene/peak loadings. They reject stale differential results if model weights,
# counts, the inference graph or grouping labels changed. Rerun the differential
# cell after such changes. Following an intentional decoder update, first call
# `model.prepare_gp_analysis(overwrite=True)`. Retraining refreshes orientation
# automatically. Do not bypass the check by flipping scores manually.

# %%
if enriched_gps:
    plot_label = f"log_bayes_factor_{log_bayes_factor_thresh}_cluster_{selected_cats[0] if selected_cats else 'all'}_vs_rest"
    save_figs = True

    generate_enriched_gp_info_plots(
        plot_label=plot_label,
        model=model,
        sample_key=sample_key,
        differential_gp_test_results_key=differential_gp_test_results_key,
        cat_key=latent_cluster_key,
        cat_palette=latent_cluster_colors,
        n_top_enriched_gp_start_idx=0,
        n_top_enriched_gp_end_idx=10,
        feature_spaces=samples, # ["latent"]
        n_top_genes_per_gp=3,
        save_figs=save_figs,
        figure_folder_path=f"{figure_folder_path}/",
        spot_size=spot_size)
else:
    print('No higher-activity GPs passed the cutoff; skipping detailed plots.')

# %% [markdown]
# #### 6.3.4 Cell-cell communication

# %% [markdown]
# Communication requires an active **prior GP with both measured source and target
# genes**. Target-only regulatory programs and add-on GPs are not eligible for this
# calculation. We show the eligible higher-activity hits and use the publication
# example when it is present, otherwise the first eligible hit. If there are no
# eligible hits, we skip this part instead of assuming a particular GP was enriched.
#
# Pass `sample_key` to keep spatial edges within independent samples, even when
# different sections have overlapping coordinate systems. The graph cache checks
# coordinates, sample labels, row order and neighbor count. The communication
# calculation pairs raw activities with raw loadings; their product is invariant
# to the shared sign correction. Its normalized strength is descriptive communication
# potential, not evidence of a causal interaction.

# %%
preferred_gp = "TRH_combined_GP"
communication_candidates = gp_quality.loc[
    gp_quality["gp_active"] & (gp_quality["gp_type"] == "prior")
    & (gp_quality["n_source_genes"] > 0) & (gp_quality["n_target_genes"] > 0)
    & gp_quality["gp_name"].isin(enriched_gps), "gp_name"].tolist()
display(gp_quality.loc[gp_quality["gp_name"].isin(communication_candidates),
                      ["gp_name", "n_source_genes", "n_target_genes", "orientation_status"]])
gp_name = (preferred_gp if preferred_gp in communication_candidates else
           communication_candidates[0] if communication_candidates else None)

# %%
if gp_name is not None:
    network_df = compute_communication_gp_network(
        sample_key=sample_key,
        gp_list=[gp_name],
        model=model,
        group_key=latent_cluster_key,
        n_neighbors=n_neighbors)

    display(network_df.head(10))
    if not network_df.empty:
        visualize_communication_gp_network(
            adata=model.adata,
            network_df=network_df,
            figsize=(9, 7),
            cat_colors=latent_cluster_colors,
            edge_type_colors=["#1f77b4"], 
            cat_key=latent_cluster_key,
            save=True,
            save_path=f"{figure_folder_path}/gp_network_{gp_name}.svg",
            )
    else:
        print("No positive normalized communication edges were found.")
else:
    print("No eligible higher-activity prior GP; skipping communication analysis.")
