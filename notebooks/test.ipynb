# %% [markdown]
# # NicheCompass Multimodal Tutorial

# %% [markdown]
# - **Creator**: Sebastian Birk (<sebastian.birk@helmholtz-munich.de>).
# - **Affiliation:** Helmholtz Munich, Institute of Computational Biology (ICB), Talavera-López Lab
# - **Date of Creation:** 18.05.2023
# - **Date of Last Modification:** 08.06.2023

# %% [markdown]
# In this tutorial, we apply NicheCompass to a single multimodal sample (postnatal day 22 coronal section) of a spatial ATAC-RNA-seq mouse brain dataset from [Zhang, D. et al. Spatial epigenome–transcriptome co-profiling of mammalian tissues. Nature 1–10 (2023)](https://www.nature.com/articles/s41586-023-05795-1).
#
# The sample has:
# - 9215 observations at spot resolution with spot rna cluster and atac cluster annotations
# - 22,914 probed genes
# - 121,068 called peaks

# %% [markdown]
# - Check the repository [README.md](https://github.com/sebastianbirk/nichecompass#installation) for NicheCompass installation instructions.
# - The data for this tutorial can be downloaded from [OneDrive](https://1drv.ms/f/s!Atya0VClQocLgvRFj0hYrFICVi0C2w?e=2uLfVX). It has to be stored under ```<repository_root>/data/spatial_omics/```.
#     - spatial_atac_rna_seq_mouse_brain_atac.h5ad
#     - spatial_atac_rna_seq_mouse_brain.h5ad
# - A pretrained model to run only the analysis can be downloaded from [OneDrive](https://1drv.ms/f/s!Atya0VClQocLgvRFj0hYrFICVi0C2w?e=2uLfVX). It has to be stored under ```<repository_root>/artifacts/multimodal/<timestamp>/model/```.
#     - 02062023_151955

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import squidpy as sq
from matplotlib import gridspec

from nichecompass.models import NicheCompass
from nichecompass.utils import (add_gps_from_gp_dict_to_adata,
                                add_multimodal_mask_to_adata,
                                aggregate_obsp_matrix_per_cell_type,
                                create_cell_type_chord_plot_from_df,
                                extract_gp_dict_from_mebocost_es_interactions,
                                extract_gp_dict_from_nichenet_ligand_target_mx,
                                extract_gp_dict_from_omnipath_lr_interactions,
                                filter_and_combine_gp_dict_gps,
                                get_gene_annotations,
                                generate_enriched_gp_info_plots,
                                generate_multimodal_pairing_dict,
                                get_unique_genes_from_gp_dict)

from color_utils import (latent_cluster_colors,
                         spatial_atac_rna_seq_mouse_embryo_and_brain_rna_colors as rna_cluster_colors,
                         spatial_atac_rna_seq_mouse_embryo_and_brain_atac_colors as atac_cluster_colors)
# Out:
# /home/cartalop/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/cartalop/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/cartalop/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/cartalop/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# ### 1.2 Define Parameters

# %%
### Dataset ###
spatial_key = "spatial"
n_neighbors = 8
filter_genes = True
n_hvg = 3000
filter_peaks = True
min_cell_peak_thresh_ratio = 0.0005 # 0.05%

### Model ###
# AnnData keys
counts_key = "counts"
adj_key = "spatial_connectivities"
condition_key = "batch"
gp_names_key = "nichecompass_gp_names"
active_gp_names_key = "nichecompass_active_gp_names"
gp_targets_mask_key = "nichecompass_gp_targets"
gp_sources_mask_key = "nichecompass_gp_sources"
latent_key = "nichecompass_latent"

# Architecture
active_gp_thresh_ratio = 0.05
node_label_method = "one-hop-norm" # choose one-hop-attention for more performant model training

# Trainer
n_epochs = 100
n_epochs_all_gps = 25
lr = 0.001
lambda_edge_recon = 500000.
lambda_gene_expr_recon = 300.
lambda_chrom_access_recon = 100.
lambda_l1_masked = 5.
edge_batch_size = 4096 # reduce if not enough memory
use_cuda_if_available = False

### Analysis ###
rna_cluster_key = "RNA_clusters"
atac_cluster_key = "ATAC_clusters"
latent_leiden_resolution = 0.6
latent_cluster_key = f"latent_leiden_{str(latent_leiden_resolution)}"
sample_key = "batch"
samples = ["p22"]
spot_size = 30
agg_weights_key = "agg_weights"
differential_gp_test_results_key = "nichecompass_differential_gp_test_results"

# %% [markdown]
# ### 1.3 Run Notebook Setup

# %%
warnings.filterwarnings("ignore")

# %%
# Get time of notebook execution for timestamping saved artifacts
now = datetime.now()
current_timestamp = now.strftime("%d%m%Y_%H%M%S")

# %% [markdown]
# ### 1.4 Configure Paths

# %%
# Define paths
ga_data_folder_path = "../data/gene_annotations"
gp_data_folder_path = "../data/gene_programs"
so_data_folder_path = "../data/spatial_omics"
omnipath_ligand_receptor_interactions_file_path = f"{gp_data_folder_path}/omnipath_lr_interactions.csv"
nichenet_ligand_target_interactions_file_path = f"{gp_data_folder_path}/nichenet_ligand_target_matrix.csv"
mebocost_enzyme_sensor_interactions_folder_path = f"{gp_data_folder_path}/metabolite_enzyme_sensor_gps"
gtf_file_path = f"{ga_data_folder_path}/gencode.vM32.chr_patch_hapl_scaff.annotation.gtf.gz"
artifacts_folder_path = f"../artifacts"
model_folder_path = f"{artifacts_folder_path}/multimodal/{current_timestamp}/model"

# %% [markdown]
# ## 2. Model Preparation

# %% [markdown]
# ### 2.1 Create Prior Knowledge Cell-Cell-Interaction (CCI) Gene Program (GP) Mask

# %% [markdown]
# - NicheCompass expects a prior CCI GP mask as input, which it will use to make its latent embedding interpretable (through a linear masked decoder).
# - The user can provide a custom GP mask to NicheCompass based on the dataset, application, and hypothesis of interest.
# - As a default, we create a GP mask based on three databases of prior CCI knowledge:
#     - OmniPath
#     - NicheNet
#     - MEBOCOST

# %%
# Retrieve OmniPath GPs (source: ligand gene; target: receptor gene)
omnipath_gp_dict = extract_gp_dict_from_omnipath_lr_interactions(
    min_curation_effort=0,
    load_from_disk=False,
    save_to_disk=True,
    file_path=omnipath_ligand_receptor_interactions_file_path,
    plot_gp_gene_count_distributions=True)

# Retrieve unique source and target genes from OmniPath GPs to keep
# those genes when filtering
omnipath_genes = get_unique_genes_from_gp_dict(
    gp_dict=omnipath_gp_dict,
    retrieved_gene_entities=["sources", "targets"])

# %%
# Display example OmniPath GPs
for i, (key, value) in enumerate(omnipath_gp_dict.items()):
    if i > 2:
        break
    print(key, value)
# Out:
# BDNF_ligand_receptor_GP {'sources': ['BDNF'], 'targets': ['DRD4']}
# EPOR_ligand_receptor_GP {'sources': ['EPOR'], 'targets': ['STAT3']}
# FYN_ligand_receptor_GP {'sources': ['FYN'], 'targets': ['MAPK7']}

# %%
# Retrieve NicheNet GPs (source: ligand gene; target: target genes)
nichenet_gp_dict = extract_gp_dict_from_nichenet_ligand_target_mx(
    keep_target_genes_ratio=0.01,
    max_n_target_genes_per_gp=1000,
    load_from_disk=False,
    save_to_disk=True,
    file_path=nichenet_ligand_target_interactions_file_path,
    plot_gp_gene_count_distributions=True)

# Retrieve unique source genes from NicheNet GPs to keep
# those genes when filtering
nichenet_source_genes = get_unique_genes_from_gp_dict(
    gp_dict=nichenet_gp_dict,
    retrieved_gene_entities=["sources"])
# Out:
# Downloading NicheNet ligand target potential matrix from the web. This might take a while...

# %%
# Display example NicheNet GPs
for i, (key, value) in enumerate(nichenet_gp_dict.items()):
    if i > 2:
        break
    print(key, value)
# Out:
# CXCL1_ligand_targetgenes_GP {'sources': ['CXCL1'], 'targets': ['COL1A1', 'HMOX1']}
# CXCL2_ligand_targetgenes_GP {'sources': ['CXCL2'], 'targets': ['GRK2', 'GRK5', 'TIMP3']}
# CXCL3_ligand_targetgenes_GP {'sources': ['CXCL3'], 'targets': ['VEGFA']}

# %%
# Retrieve MEBOCOST GPs (source: enzyme genes; target: sensor genes)
mebocost_gp_dict = extract_gp_dict_from_mebocost_es_interactions(
    dir_path=mebocost_enzyme_sensor_interactions_folder_path,
    species="mouse",
    genes_uppercase=True,
    plot_gp_gene_count_distributions=True)

# Retrieve unique source and target genes from MEBOCOST GPs to keep
# those genes when filtering
mebocost_genes = get_unique_genes_from_gp_dict(
    gp_dict=mebocost_gp_dict,
    retrieved_gene_entities=["sources", "targets"])

# %%
# Display example MEBOCOST GPs
for i, (key, value) in enumerate(mebocost_gp_dict.items()):
    if i > 2:
        break
    print(key, value)
# Out:
# Deoxyuridine_metabolite_enzyme_sensor_GP {'sources': ['CDA', 'PNP', 'PNP2', 'TK1', 'TK2', 'TYMP'], 'targets': ['SLC29A2']}
# Deoxycytidine_metabolite_enzyme_sensor_GP {'sources': ['CDA', 'DCK', 'NT5C', 'NT5C1A', 'NT5C1B', 'NT5C2', 'NT5E', 'NT5M'], 'targets': ['SLC29A2']}
# 3-Methoxytyramine_metabolite_enzyme_sensor_GP {'sources': ['COMT', 'MAOA', 'MAOB'], 'targets': ['TAAR1']}

# %%
# Add GPs into one combined dictionary
# for model training
combined_gp_dict = dict(omnipath_gp_dict)
combined_gp_dict.update(nichenet_gp_dict)
combined_gp_dict.update(mebocost_gp_dict)

# %%
# Filter and combine GPs to avoid overlaps
combined_new_gp_dict = filter_and_combine_gp_dict_gps(
    gp_dict=combined_gp_dict,
    gp_filter_mode="subset",
    combine_overlap_gps=True,
    overlap_thresh_source_genes=0.9,
    overlap_thresh_target_genes=0.9,
    overlap_thresh_genes=0.9)

print("Number of gene programs before filtering and combining: "
      f"{len(combined_gp_dict)}.")
print(f"Number of gene programs after filtering and combining: "
      f"{len(combined_new_gp_dict)}.")
# Out:
# Number of gene programs before filtering and combining: 1725.
# Number of gene programs after filtering and combining: 1583.

# %% [markdown]
# ### 2.2 Load Data & Compute Spatial Neighbor Graph

# %% [markdown]
# - NicheCompass expects a precomputed spatial adjacency matrix stored in 'adata.obsp[adj_key]'.
# - The user can customize the spatial neighbor graph construction based on the dataset, application, and hypothesis of interest.
# - In the multimodal setting, we will provide one adata object per modality to NicheCompass.

# %%
# Read data
adata = sc.read_h5ad(
        f"{so_data_folder_path}/spatial_atac_rna_seq_mouse_brain.h5ad")
adata_atac = sc.read_h5ad(
        f"{so_data_folder_path}/spatial_atac_rna_seq_mouse_brain_atac.h5ad")

# %%
# Compute (separate) spatial neighborhood graphs
sq.gr.spatial_neighbors(adata,
                        coord_type="generic",
                        spatial_key=spatial_key,
                        n_neighs=n_neighbors)

# Make adjacency matrix symmetric
adata.obsp[adj_key] = (
    adata.obsp[adj_key].maximum(
        adata.obsp[adj_key].T))

# %% [markdown]
# ### 2.3 Filter Genes & Peaks

# %%
if filter_genes:
    print("Filtering genes...")
    # Filter genes and only keep ligand, receptor, metabolite enzyme, 
    # metabolite sensor and the 'n_hvg' highly variable genes (potential target
    # genes of nichenet)
    gp_dict_genes = get_unique_genes_from_gp_dict(
        gp_dict=combined_new_gp_dict,
            retrieved_gene_entities=["sources", "targets"])
    print(f"Starting with {len(adata.var_names)} genes.")
    sc.pp.filter_genes(adata,
                       min_cells=0)
    print(f"Keeping {len(adata.var_names)} genes after filtering genes with "
          "expression in 0 cells.")

    sc.pp.highly_variable_genes(
        adata,
        layer=counts_key,
        n_top_genes=n_hvg,
        flavor="seurat_v3",
        subset=False)

    # Get gene program relevant genes
    gp_relevant_genes = list(set(omnipath_genes + 
                                 nichenet_source_genes + 
                                 mebocost_genes))
    
    adata.var["gp_relevant"] = (
        adata.var.index.str.upper().isin(gp_relevant_genes))
    adata.var["keep_gene"] = (adata.var["gp_relevant"] | 
                              adata.var["highly_variable"])
    adata = adata[:, adata.var["keep_gene"] == True]
    print(f"Keeping {len(adata.var_names)} highly variable or gene program "
          "relevant genes.")
    adata = (adata[:, adata.var_names[adata.var_names.str.upper().isin(
                gp_dict_genes)].sort_values()])
    print(f"Keeping {len(adata.var_names)} genes after filtering genes not in "
          "gp dict.")
    
if filter_peaks:
    print("\nFiltering peaks...")
    print(f"Starting with {len(adata_atac.var_names)} peaks.")
    # Filter out peaks that are rarely detected to reduce GPU footprint of model
    min_cells = int(adata_atac.shape[0] * min_cell_peak_thresh_ratio)
    sc.pp.filter_genes(adata_atac, min_cells=min_cells)
    print(f"Keeping {len(adata_atac.var_names)} peaks after filtering peaks with "
          f"counts in less than {int(adata_atac.shape[0] * min_cell_peak_thresh_ratio)} cells.")
# Out:
# Filtering genes...
# Starting with 22914 genes.
# Keeping 22914 genes after filtering genes with expression in 0 cells.
# Keeping 4962 highly variable or gene program relevant genes.
# Keeping 3715 genes after filtering genes not in gp dict.
#
# Filtering peaks...
# Starting with 121068 peaks.
# Keeping 121068 peaks after filtering peaks with counts in less than 4 cells.

# %% [markdown]
# ### 2.4 Annotate Genes & Peaks

# %% [markdown]
# Next, we will add positional annotations to genes and peaks to be able to match spatially proximal peaks to genes.

# %%
adata, adata_atac = get_gene_annotations(
    adata=adata,
    adata_atac=adata_atac,
    gtf_file_path=gtf_file_path)

# %%
# Display gene annotations
adata.var[["chrom", "chromStart", "chromEnd"]]
# Out:
#          chrom   chromStart     chromEnd
# A2m       chr6  121612334.0  121656186.0
# Aacs      chr5  125552877.0  125594474.0
# Aadat     chr8   60958965.0   60998711.0
# Aanat    chr11  116477257.0  116488506.0
# Aars2    chr17   45817766.0   45831769.0
# ...        ...          ...          ...
# Zp3       chr5  136008952.0  136017478.0
# Zpbp2    chr11   98441922.0   98449491.0
# Zscan25   chr5  145217309.0  145228088.0
# Zw10      chr9   48966912.0   48990075.0
# Zwilch    chr9   64044425.0   64080386.0
#
# [3677 rows x 3 columns]

# %%
# Display peak annotations
adata_atac.var[["chrom", "chromStart", "chromEnd"]]
# Out:
#                              chrom  chromStart  chromEnd
# chr1:3094734-3095650          chr1     3094734   3095650
# chr1:3119757-3120179          chr1     3119757   3120179
# chr1:3120267-3120653          chr1     3120267   3120653
# chr1:3121314-3122051          chr1     3121314   3122051
# chr1:3264998-3265766          chr1     3264998   3265766
# ...                            ...         ...       ...
# GL456216.1:31908-32576  GL456216.1       31908     32576
# GL456216.1:43983-44510  GL456216.1       43983     44510
# GL456216.1:48771-49683  GL456216.1       48771     49683
# JH584292.1:12571-13497  JH584292.1       12571     13497
# JH584295.1:1163-1976    JH584295.1        1163      1976
#
# [121068 rows x 3 columns]

# %% [markdown]
# ### 2.5 Add GP Mask to Data

# %%
# Add the GP dictionary as binary masks to the adata
add_gps_from_gp_dict_to_adata(
    gp_dict=combined_new_gp_dict,
    adata=adata,
    gp_targets_mask_key=gp_targets_mask_key,
    gp_sources_mask_key=gp_sources_mask_key,
    gp_names_key=gp_names_key,
    min_genes_per_gp=1,
    min_source_genes_per_gp=0,
    min_target_genes_per_gp=0,
    max_genes_per_gp=None,
    max_source_genes_per_gp=None,
    max_target_genes_per_gp=None)

# %% [markdown]
# ### 2.6 Add Chromatin Accessibility Mask to Data

# %% [markdown]
# Based on spatial proximity to the genes in the GP mask, we will add a chromatin accessibility mask.

# %%
gene_peak_dict = generate_multimodal_pairing_dict(
    adata,
    adata_atac)
# Out:
# window_graph:   0%|          | 0/3677 [00:00<?, ?it/s]

# %%
adata, adata_atac = add_multimodal_mask_to_adata(
    adata=adata,
    adata_atac=adata_atac,
    gene_peak_mapping_dict=gene_peak_dict)

print(f"Keeping {len(adata_atac.var_names)} peaks after filtering peaks with "
      "no matching genes in gp mask.")
# Out:
# Keeping 17078 peaks after filtering peaks with no matching genes in gp mask.

# %% [markdown]
# ### 2.7 Explore Data

# %%
print(f"Number of nodes (observations): {adata.layers['counts'].shape[0]}")
print(f"Number of gene node features: {adata.layers['counts'].shape[1]}")
print(f"Number of peak node features: {adata_atac.layers['counts'].shape[1]}")

# Visualize spot-level annotated data in physical space
sc.pl.spatial(adata,
              color=rna_cluster_key,
              spot_size=spot_size)
sc.pl.spatial(adata_atac,
              color=atac_cluster_key,
              spot_size=spot_size)
# Out:
# Number of nodes (observations): 9215
# Number of gene node features: 3677
# Number of peak node features: 17078

# %% [markdown]
# ## 3. Model Training

# %% [markdown]
# ### 3.1 Initialize, Train & Save Model

# %%
adata_test = adata[:6]

# %%
adata_atac_test = adata_atac[:6]

# %%
# Initialize model
model = NicheCompass(adata,
                     adata_atac,
                     counts_key=counts_key,
                     adj_key=adj_key,
                     condition_key=condition_key,
                     gp_names_key=gp_names_key,
                     active_gp_names_key=active_gp_names_key,
                     gp_targets_mask_key=gp_targets_mask_key,
                     gp_sources_mask_key=gp_sources_mask_key,
                     latent_key=latent_key,
                     active_gp_thresh_ratio=active_gp_thresh_ratio,
                     node_label_method=node_label_method)
# Out:
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb, include_chrom_access_recon_loss: True, chrom_access_recon_dist: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.05
# LOG VARIATIONAL -> True
# CONDITIONAL EMBEDDING INJECTION -> ['gene_expr_decoder', 'chrom_access_decoder']
# ENCODER -> n_input: 20755, n_cond_embed_input: 0, n_layers: 1, n_hidden: 1486, n_latent: 1486, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0
# COSINE SIM GRAPH DECODER -> n_cond_embed_input: 0, n_cond_embed_output: 1486, dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 1486, n_cond_embed_input: 1486, n_addon_input: 0, n_output: 7354
# MASKED CHROMATIN ACCESSIBILITY DECODER -> n_input: 1486, n_cond_embed_input: 1486, n_addon_input: 0, n_output: 34156
# ONE HOP GCN NORM NODE LABEL AGGREGATOR

# %%
edge_batch_size = 2
node_batch_size = 2

# %%
del(model)
import gc
gc.collect()
# Out:
# 3081

# %%
# Train model
model.train(n_epochs=n_epochs,
            n_epochs_all_gps=n_epochs_all_gps,
            lr=lr,
            lambda_edge_recon=lambda_edge_recon,
            lambda_gene_expr_recon=lambda_gene_expr_recon,
            lambda_chrom_access_recon=lambda_chrom_access_recon,
            lambda_l1_masked=lambda_l1_masked,
            edge_batch_size=edge_batch_size,
            use_cuda_if_available=use_cuda_if_available,
            verbose=True)
# Out:
# --- INITIALIZING TRAINER ---
# Number of training nodes: 8293
# Number of validation nodes: 922
# Number of training edges: 33399
# Number of validation edges: 3711
# Edge batch size: 4096
# Node batch size: None
#
# --- MODEL TRAINING ---
# Epoch 1/100 |--------------------| 1.0% val_auroc_score: 0.8776; val_auprc_score: 0.8936; val_best_acc_score: 0.6040; val_best_f1_score: 0.7130; train_kl_reg_loss: 4514.9449; train_edge_recon_loss: 347874.5382; train_gene_expr_recon_loss: 437880.2361; train_masked_gp_l1_reg_loss: 2844.3671; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 519453.6354; train_global_loss: 1312567.7222; train_optim_loss: 1312567.7222; val_kl_reg_loss: 3833.5640; val_edge_recon_loss: 405945.7500; val_gene_expr_recon_loss: 391973.3750; val_masked_gp_l1_reg_loss: 2116.9773; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 500194.2500; val_global_loss: 1304064.0000; val_optim_loss: 1304064.0000
# Epoch 2/100 |--------------------| 2.0% val_auroc_score: 0.8647; val_auprc_score: 0.8751; val_best_acc_score: 0.7700; val_best_f1_score: 0.7727; train_kl_reg_loss: 2249.9483; train_edge_recon_loss: 347289.9236; train_gene_expr_recon_loss: 382963.3889; train_masked_gp_l1_reg_loss: 1691.0329; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 496581.2188; train_global_loss: 1230775.5556; train_optim_loss: 1230775.5556; val_kl_reg_loss: 2214.7529; val_edge_recon_loss: 403298.5625; val_gene_expr_recon_loss: 378814.1250; val_masked_gp_l1_reg_loss: 1240.3822; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 492923.5312; val_global_loss: 1278491.3750; val_optim_loss: 1278491.3750
# Epoch 3/100 |--------------------| 3.0% val_auroc_score: 0.8574; val_auprc_score: 0.8614; val_best_acc_score: 0.7385; val_best_f1_score: 0.7809; train_kl_reg_loss: 1869.9977; train_edge_recon_loss: 346613.8333; train_gene_expr_recon_loss: 372003.2292; train_masked_gp_l1_reg_loss: 1016.5167; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 489659.3264; train_global_loss: 1211162.8750; train_optim_loss: 1211162.8750; val_kl_reg_loss: 1468.7717; val_edge_recon_loss: 394890.0312; val_gene_expr_recon_loss: 373796.3438; val_masked_gp_l1_reg_loss: 818.5284; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 489759.2188; val_global_loss: 1260732.8750; val_optim_loss: 1260732.8750
# Epoch 4/100 |--------------------| 4.0% val_auroc_score: 0.8474; val_auprc_score: 0.8346; val_best_acc_score: 0.7653; val_best_f1_score: 0.7918; train_kl_reg_loss: 1520.9847; train_edge_recon_loss: 342507.8750; train_gene_expr_recon_loss: 368199.6840; train_masked_gp_l1_reg_loss: 706.8830; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 491569.3090; train_global_loss: 1204504.7500; train_optim_loss: 1204504.7500; val_kl_reg_loss: 1946.8716; val_edge_recon_loss: 320475.5000; val_gene_expr_recon_loss: 371063.2812; val_masked_gp_l1_reg_loss: 572.7761; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 488324.1250; val_global_loss: 1182382.5000; val_optim_loss: 1182382.5000
# Epoch 5/100 |█-------------------| 5.0% val_auroc_score: 0.8566; val_auprc_score: 0.8502; val_best_acc_score: 0.7607; val_best_f1_score: 0.7773; train_kl_reg_loss: 5042.1043; train_edge_recon_loss: 304672.6146; train_gene_expr_recon_loss: 366535.8924; train_masked_gp_l1_reg_loss: 493.5322; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 487919.4653; train_global_loss: 1164663.5972; train_optim_loss: 1164663.5972; val_kl_reg_loss: 8749.6426; val_edge_recon_loss: 294520.5312; val_gene_expr_recon_loss: 369338.0000; val_masked_gp_l1_reg_loss: 410.0642; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 487784.6250; val_global_loss: 1160802.8750; val_optim_loss: 1160802.8750
# Epoch 6/100 |█-------------------| 6.0% val_auroc_score: 0.8445; val_auprc_score: 0.8212; val_best_acc_score: 0.7716; val_best_f1_score: 0.7916; train_kl_reg_loss: 10237.0697; train_edge_recon_loss: 285923.9792; train_gene_expr_recon_loss: 363913.8715; train_masked_gp_l1_reg_loss: 362.5018; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 484628.2153; train_global_loss: 1145065.6250; train_optim_loss: 1145065.6250; val_kl_reg_loss: 10261.5205; val_edge_recon_loss: 285571.9688; val_gene_expr_recon_loss: 368629.3125; val_masked_gp_l1_reg_loss: 314.1715; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 487284.3125; val_global_loss: 1152061.2500; val_optim_loss: 1152061.2500
# Epoch 7/100 |█-------------------| 7.0% val_auroc_score: 0.8519; val_auprc_score: 0.8175; val_best_acc_score: 0.8033; val_best_f1_score: 0.8274; train_kl_reg_loss: 9273.2891; train_edge_recon_loss: 282495.3507; train_gene_expr_recon_loss: 363263.0938; train_masked_gp_l1_reg_loss: 288.1520; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 484903.8021; train_global_loss: 1140223.6944; train_optim_loss: 1140223.6944; val_kl_reg_loss: 7442.9844; val_edge_recon_loss: 278588.6562; val_gene_expr_recon_loss: 367792.3125; val_masked_gp_l1_reg_loss: 260.3460; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 486886.9062; val_global_loss: 1140971.2500; val_optim_loss: 1140971.2500
# Epoch 8/100 |█-------------------| 8.0% val_auroc_score: 0.8890; val_auprc_score: 0.8608; val_best_acc_score: 0.8248; val_best_f1_score: 0.8426; train_kl_reg_loss: 6779.6671; train_edge_recon_loss: 276923.7882; train_gene_expr_recon_loss: 364304.1632; train_masked_gp_l1_reg_loss: 245.0223; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 488471.2326; train_global_loss: 1136723.8611; train_optim_loss: 1136723.8611; val_kl_reg_loss: 5869.8335; val_edge_recon_loss: 273093.8750; val_gene_expr_recon_loss: 367484.0625; val_masked_gp_l1_reg_loss: 228.1530; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 486594.6250; val_global_loss: 1133270.5000; val_optim_loss: 1133270.5000
# Epoch 9/100 |█-------------------| 9.0% val_auroc_score: 0.9036; val_auprc_score: 0.8823; val_best_acc_score: 0.8324; val_best_f1_score: 0.8474; train_kl_reg_loss: 6102.7264; train_edge_recon_loss: 275552.0243; train_gene_expr_recon_loss: 362654.8160; train_masked_gp_l1_reg_loss: 220.0548; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 485274.3993; train_global_loss: 1129804.0556; train_optim_loss: 1129804.0556; val_kl_reg_loss: 6348.1396; val_edge_recon_loss: 274094.6875; val_gene_expr_recon_loss: 367005.1875; val_masked_gp_l1_reg_loss: 211.4813; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 486384.6250; val_global_loss: 1134044.1250; val_optim_loss: 1134044.1250
# Epoch 10/100 |██------------------| 10.0% val_auroc_score: 0.9081; val_auprc_score: 0.8871; val_best_acc_score: 0.8395; val_best_f1_score: 0.8528; train_kl_reg_loss: 6964.2116; train_edge_recon_loss: 272000.4549; train_gene_expr_recon_loss: 361971.4097; train_masked_gp_l1_reg_loss: 207.5366; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 484155.0694; train_global_loss: 1125298.6667; train_optim_loss: 1125298.6667; val_kl_reg_loss: 6993.8975; val_edge_recon_loss: 272602.6250; val_gene_expr_recon_loss: 366616.4688; val_masked_gp_l1_reg_loss: 204.1390; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 486018.5625; val_global_loss: 1132435.7500; val_optim_loss: 1132435.7500
# Epoch 11/100 |██------------------| 11.0% val_auroc_score: 0.9126; val_auprc_score: 0.8916; val_best_acc_score: 0.8468; val_best_f1_score: 0.8598; train_kl_reg_loss: 7003.8817; train_edge_recon_loss: 271268.2986; train_gene_expr_recon_loss: 361790.2257; train_masked_gp_l1_reg_loss: 204.0947; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 483366.3125; train_global_loss: 1123632.7917; train_optim_loss: 1123632.7917; val_kl_reg_loss: 6417.4307; val_edge_recon_loss: 271891.2500; val_gene_expr_recon_loss: 366243.6250; val_masked_gp_l1_reg_loss: 203.5072; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 485650.8750; val_global_loss: 1130406.7500; val_optim_loss: 1130406.7500
# Epoch 12/100 |██------------------| 12.0% val_auroc_score: 0.9182; val_auprc_score: 0.8982; val_best_acc_score: 0.8514; val_best_f1_score: 0.8618; train_kl_reg_loss: 6465.2887; train_edge_recon_loss: 272456.5729; train_gene_expr_recon_loss: 360166.9826; train_masked_gp_l1_reg_loss: 204.8080; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 482858.5833; train_global_loss: 1122152.2361; train_optim_loss: 1122152.2361; val_kl_reg_loss: 6073.1455; val_edge_recon_loss: 273209.0938; val_gene_expr_recon_loss: 365830.7812; val_masked_gp_l1_reg_loss: 205.9696; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 485256.0000; val_global_loss: 1130575.0000; val_optim_loss: 1130575.0000
# Epoch 13/100 |██------------------| 13.0% val_auroc_score: 0.9232; val_auprc_score: 0.9036; val_best_acc_score: 0.8583; val_best_f1_score: 0.8686; train_kl_reg_loss: 6243.9569; train_edge_recon_loss: 270810.0521; train_gene_expr_recon_loss: 361165.6910; train_masked_gp_l1_reg_loss: 208.1056; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 484031.7847; train_global_loss: 1122459.6111; train_optim_loss: 1122459.6111; val_kl_reg_loss: 6029.2529; val_edge_recon_loss: 270003.0625; val_gene_expr_recon_loss: 365543.0312; val_masked_gp_l1_reg_loss: 210.7685; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 484968.6875; val_global_loss: 1126754.7500; val_optim_loss: 1126754.7500
# Epoch 14/100 |██------------------| 14.0% val_auroc_score: 0.9280; val_auprc_score: 0.9095; val_best_acc_score: 0.8599; val_best_f1_score: 0.8698; train_kl_reg_loss: 6251.7623; train_edge_recon_loss: 271307.5590; train_gene_expr_recon_loss: 359563.8993; train_masked_gp_l1_reg_loss: 213.9327; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 483383.1319; train_global_loss: 1120720.3056; train_optim_loss: 1120720.3056; val_kl_reg_loss: 6061.2358; val_edge_recon_loss: 271233.6250; val_gene_expr_recon_loss: 365090.5000; val_masked_gp_l1_reg_loss: 217.0027; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 484454.9688; val_global_loss: 1127057.3750; val_optim_loss: 1127057.3750
# Epoch 15/100 |███-----------------| 15.0% val_auroc_score: 0.9332; val_auprc_score: 0.9162; val_best_acc_score: 0.8690; val_best_f1_score: 0.8774; train_kl_reg_loss: 6158.4971; train_edge_recon_loss: 269714.3993; train_gene_expr_recon_loss: 360482.3472; train_masked_gp_l1_reg_loss: 220.4040; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 481153.0799; train_global_loss: 1117728.7083; train_optim_loss: 1117728.7083; val_kl_reg_loss: 5945.9912; val_edge_recon_loss: 268354.7188; val_gene_expr_recon_loss: 364895.6562; val_masked_gp_l1_reg_loss: 224.0970; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 484316.1562; val_global_loss: 1123736.6250; val_optim_loss: 1123736.6250
# Epoch 16/100 |███-----------------| 16.0% val_auroc_score: 0.9423; val_auprc_score: 0.9253; val_best_acc_score: 0.8802; val_best_f1_score: 0.8882; train_kl_reg_loss: 6097.2773; train_edge_recon_loss: 270193.6493; train_gene_expr_recon_loss: 359289.6528; train_masked_gp_l1_reg_loss: 228.3315; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 481871.3542; train_global_loss: 1117680.2778; train_optim_loss: 1117680.2778; val_kl_reg_loss: 5947.5571; val_edge_recon_loss: 267097.2500; val_gene_expr_recon_loss: 364417.3750; val_masked_gp_l1_reg_loss: 232.2749; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 483936.9062; val_global_loss: 1121631.3750; val_optim_loss: 1121631.3750
# Epoch 17/100 |███-----------------| 17.0% val_auroc_score: 0.9406; val_auprc_score: 0.9190; val_best_acc_score: 0.8787; val_best_f1_score: 0.8862; train_kl_reg_loss: 5989.8659; train_edge_recon_loss: 270468.8056; train_gene_expr_recon_loss: 359019.5000; train_masked_gp_l1_reg_loss: 236.5025; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 482024.3264; train_global_loss: 1117738.9722; train_optim_loss: 1117738.9722; val_kl_reg_loss: 5691.9316; val_edge_recon_loss: 267258.8750; val_gene_expr_recon_loss: 364220.3750; val_masked_gp_l1_reg_loss: 239.6155; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 483434.0312; val_global_loss: 1120844.8750; val_optim_loss: 1120844.8750
# Epoch 18/100 |███-----------------| 18.0% val_auroc_score: 0.9467; val_auprc_score: 0.9297; val_best_acc_score: 0.8867; val_best_f1_score: 0.8932; train_kl_reg_loss: 5917.3832; train_edge_recon_loss: 270056.1146; train_gene_expr_recon_loss: 360345.1840; train_masked_gp_l1_reg_loss: 243.2518; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480529.4549; train_global_loss: 1117091.3750; train_optim_loss: 1117091.3750; val_kl_reg_loss: 5659.0522; val_edge_recon_loss: 267566.0625; val_gene_expr_recon_loss: 363868.2812; val_masked_gp_l1_reg_loss: 247.0328; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 483237.1250; val_global_loss: 1120577.5000; val_optim_loss: 1120577.5000
# Epoch 19/100 |███-----------------| 19.0% val_auroc_score: 0.9497; val_auprc_score: 0.9343; val_best_acc_score: 0.8901; val_best_f1_score: 0.8966; train_kl_reg_loss: 5852.0456; train_edge_recon_loss: 268111.3542; train_gene_expr_recon_loss: 358197.1875; train_masked_gp_l1_reg_loss: 251.3508; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 481055.9965; train_global_loss: 1113467.9028; train_optim_loss: 1113467.9028; val_kl_reg_loss: 5803.9478; val_edge_recon_loss: 266555.9688; val_gene_expr_recon_loss: 363440.8125; val_masked_gp_l1_reg_loss: 254.6302; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 482777.7500; val_global_loss: 1118833.1250; val_optim_loss: 1118833.1250
# Epoch 20/100 |████----------------| 20.0% val_auroc_score: 0.9554; val_auprc_score: 0.9398; val_best_acc_score: 0.9002; val_best_f1_score: 0.9048; train_kl_reg_loss: 6018.6513; train_edge_recon_loss: 267174.6736; train_gene_expr_recon_loss: 357731.8507; train_masked_gp_l1_reg_loss: 258.2961; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480834.5035; train_global_loss: 1112018.0000; train_optim_loss: 1112018.0000; val_kl_reg_loss: 5757.7988; val_edge_recon_loss: 264413.5312; val_gene_expr_recon_loss: 363295.5312; val_masked_gp_l1_reg_loss: 261.7987; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 482607.4375; val_global_loss: 1116336.1250; val_optim_loss: 1116336.1250
# Epoch 21/100 |████----------------| 21.0% val_auroc_score: 0.9555; val_auprc_score: 0.9416; val_best_acc_score: 0.9006; val_best_f1_score: 0.9054; train_kl_reg_loss: 6125.8741; train_edge_recon_loss: 265501.6250; train_gene_expr_recon_loss: 358610.9167; train_masked_gp_l1_reg_loss: 266.0467; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 481054.6424; train_global_loss: 1111559.1111; train_optim_loss: 1111559.1111; val_kl_reg_loss: 6064.3945; val_edge_recon_loss: 267024.9062; val_gene_expr_recon_loss: 362942.6562; val_masked_gp_l1_reg_loss: 269.5999; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 482202.0625; val_global_loss: 1118503.7500; val_optim_loss: 1118503.7500
# Epoch 22/100 |████----------------| 22.0% val_auroc_score: 0.9588; val_auprc_score: 0.9436; val_best_acc_score: 0.9034; val_best_f1_score: 0.9084; train_kl_reg_loss: 6019.1759; train_edge_recon_loss: 266240.6389; train_gene_expr_recon_loss: 358339.2812; train_masked_gp_l1_reg_loss: 274.1660; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480794.9236; train_global_loss: 1111668.1806; train_optim_loss: 1111668.1806; val_kl_reg_loss: 5786.6592; val_edge_recon_loss: 266205.1562; val_gene_expr_recon_loss: 362661.8438; val_masked_gp_l1_reg_loss: 277.0770; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 481787.3125; val_global_loss: 1116718.0000; val_optim_loss: 1116718.0000
# Epoch 23/100 |████----------------| 23.0% val_auroc_score: 0.9589; val_auprc_score: 0.9466; val_best_acc_score: 0.9081; val_best_f1_score: 0.9112; train_kl_reg_loss: 5985.4098; train_edge_recon_loss: 265427.2986; train_gene_expr_recon_loss: 357451.5729; train_masked_gp_l1_reg_loss: 281.2667; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480045.9757; train_global_loss: 1109191.5139; train_optim_loss: 1109191.5139; val_kl_reg_loss: 5711.8989; val_edge_recon_loss: 264075.3750; val_gene_expr_recon_loss: 362309.9375; val_masked_gp_l1_reg_loss: 284.3471; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 481635.7500; val_global_loss: 1114017.3750; val_optim_loss: 1114017.3750
# Epoch 24/100 |████----------------| 24.0% val_auroc_score: 0.9660; val_auprc_score: 0.9558; val_best_acc_score: 0.9158; val_best_f1_score: 0.9187; train_kl_reg_loss: 5838.9230; train_edge_recon_loss: 265495.2153; train_gene_expr_recon_loss: 356311.6111; train_masked_gp_l1_reg_loss: 287.7919; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480278.8333; train_global_loss: 1108212.3472; train_optim_loss: 1108212.3472; val_kl_reg_loss: 5848.4170; val_edge_recon_loss: 262238.0000; val_gene_expr_recon_loss: 361957.3125; val_masked_gp_l1_reg_loss: 290.7805; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 481320.4062; val_global_loss: 1111654.8750; val_optim_loss: 1111654.8750
# Epoch 25/100 |█████---------------| 25.0% val_auroc_score: 0.9677; val_auprc_score: 0.9559; val_best_acc_score: 0.9181; val_best_f1_score: 0.9212; train_kl_reg_loss: 5967.9933; train_edge_recon_loss: 265970.8889; train_gene_expr_recon_loss: 358351.8472; train_masked_gp_l1_reg_loss: 293.6300; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480348.6042; train_global_loss: 1110932.9583; train_optim_loss: 1110932.9583; val_kl_reg_loss: 5487.6450; val_edge_recon_loss: 262853.2500; val_gene_expr_recon_loss: 361617.2500; val_masked_gp_l1_reg_loss: 296.4679; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 480954.9688; val_global_loss: 1111209.5000; val_optim_loss: 1111209.5000
# Epoch 26/100 |█████---------------| 26.0% val_auroc_score: 0.9673; val_auprc_score: 0.9569; val_best_acc_score: 0.9184; val_best_f1_score: 0.9210; train_kl_reg_loss: 5479.9168; train_edge_recon_loss: 265029.3194; train_gene_expr_recon_loss: 357006.9826; train_masked_gp_l1_reg_loss: 297.9241; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 478469.7569; train_global_loss: 1106283.9028; train_optim_loss: 1106283.9028; val_kl_reg_loss: 4711.1396; val_edge_recon_loss: 265154.4375; val_gene_expr_recon_loss: 361513.8750; val_masked_gp_l1_reg_loss: 296.6819; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 480635.6562; val_global_loss: 1112311.7500; val_optim_loss: 1112311.7500
# Epoch 27/100 |█████---------------| 27.0% val_auroc_score: 0.9704; val_auprc_score: 0.9625; val_best_acc_score: 0.9177; val_best_f1_score: 0.9207; train_kl_reg_loss: 5059.6635; train_edge_recon_loss: 263861.3924; train_gene_expr_recon_loss: 357203.5035; train_masked_gp_l1_reg_loss: 296.0329; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 480414.1806; train_global_loss: 1106834.7778; train_optim_loss: 1106834.7778; val_kl_reg_loss: 4611.4756; val_edge_recon_loss: 263509.9375; val_gene_expr_recon_loss: 361259.8125; val_masked_gp_l1_reg_loss: 293.3971; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 480434.7500; val_global_loss: 1110109.3750; val_optim_loss: 1110109.3750
# Epoch 28/100 |█████---------------| 28.0% val_auroc_score: 0.9693; val_auprc_score: 0.9585; val_best_acc_score: 0.9208; val_best_f1_score: 0.9236; train_kl_reg_loss: 4950.6738; train_edge_recon_loss: 262494.6597; train_gene_expr_recon_loss: 358552.5660; train_masked_gp_l1_reg_loss: 293.3510; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 481058.6528; train_global_loss: 1107349.8889; train_optim_loss: 1107349.8889; val_kl_reg_loss: 4346.0977; val_edge_recon_loss: 262222.7188; val_gene_expr_recon_loss: 360934.5000; val_masked_gp_l1_reg_loss: 292.2887; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 480110.0000; val_global_loss: 1107905.6250; val_optim_loss: 1107905.6250
# Epoch 29/100 |█████---------------| 29.0% val_auroc_score: 0.9758; val_auprc_score: 0.9659; val_best_acc_score: 0.9279; val_best_f1_score: 0.9302; train_kl_reg_loss: 4767.4595; train_edge_recon_loss: 261886.8941; train_gene_expr_recon_loss: 356261.9688; train_masked_gp_l1_reg_loss: 293.1161; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 478163.4757; train_global_loss: 1101372.9167; train_optim_loss: 1101372.9167; val_kl_reg_loss: 4478.4219; val_edge_recon_loss: 263024.3750; val_gene_expr_recon_loss: 360719.2812; val_masked_gp_l1_reg_loss: 293.0476; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 479821.3750; val_global_loss: 1108336.5000; val_optim_loss: 1108336.5000
# Epoch 30/100 |██████--------------| 30.0% val_auroc_score: 0.9761; val_auprc_score: 0.9672; val_best_acc_score: 0.9326; val_best_f1_score: 0.9344; train_kl_reg_loss: 4758.0055; train_edge_recon_loss: 262130.0729; train_gene_expr_recon_loss: 357841.4896; train_masked_gp_l1_reg_loss: 293.5015; train_group_lasso_reg_loss: 0.0000; train_chrom_access_recon_loss: 481465.4688; train_global_loss: 1106488.5278; train_optim_loss: 1106488.5278; val_kl_reg_loss: 4296.7534; val_edge_recon_loss: 263875.9375; val_gene_expr_recon_loss: 360343.4688; val_masked_gp_l1_reg_loss: 293.1058; val_group_lasso_reg_loss: 0.0000; val_chrom_access_recon_loss: 479313.9062; val_global_loss: 1108123.1250; val_optim_loss: 1108123.1250

# %%
# Compute latent neighbor graph
sc.pp.neighbors(model.adata,
                use_rep=latent_key,
                key_added=latent_key)

# Compute UMAP embedding
sc.tl.umap(model.adata,
           neighbors_key=latent_key)

# %%
# Save trained model
model.save(dir_path=model_folder_path,
           overwrite=True,
           save_adata=True,
           adata_file_name="adata.h5ad",
           save_adata_atac=True,
           adata_atac_file_name=f"adata_atac.h5ad")

# %% [markdown]
# ## 4. Analysis

# %%
load_timestamp = "11062023_113857"

figure_folder_path = f"{artifacts_folder_path}/multimodal/{load_timestamp}/figures"
model_folder_path = f"{artifacts_folder_path}/multimodal/{load_timestamp}/model"

os.makedirs(figure_folder_path, exist_ok=True)

# %%
# Load trained model
model = NicheCompass.load(dir_path=model_folder_path,
                          adata=None,
                          adata_file_name="adata.h5ad",
                          adata_atac=None,
                          adata_atac_file_name="adata_atac.h5ad",
                          gp_names_key=gp_names_key)
# Out:
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb, include_chrom_access_recon_loss: True, chrom_access_recon_dist: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.1
# LOG VARIATIONAL -> True
# CONDITIONAL EMBEDDING INJECTION -> ['gene_expr_decoder', 'chrom_access_decoder']
# ENCODER -> n_input: 20755, n_cond_embed_input: 0, n_layers: 1, n_hidden: 1486, n_latent: 1486, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0
# COSINE SIM GRAPH DECODER -> n_cond_embed_input: 0, n_cond_embed_output: 1486, dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 1486, n_cond_embed_input: 1486, n_addon_input: 0, n_output: 7354
# MASKED CHROMATIN ACCESSIBILITY DECODER -> n_input: 1486, n_cond_embed_input: 1486, n_addon_input: 0, n_output: 34156
# ONE HOP GCN NORM NODE LABEL AGGREGATOR

# %% [markdown]
# ### 4.1 Visualize NicheCompass Embeddings

# %% [markdown]
# Let's look at the preservation of rna cluster and atac cluster spot annotations in the embedding space. Note that the goal of NicheCompass is not a perfect separation of rna cluster or atac cluster spot annotations but rather to identify spatial cellular niches. Nevertheless, it can be useful to look at the spot annotations if available.

# %%
# Plot UMAP with rna cluster spot annotations
groups = None
save_fig = True
file_path = f"{figure_folder_path}/" \
            "rna_cluster_annotations_latent_space.svg"

fig = sc.pl.umap(model.adata,
                 color=[rna_cluster_key],
                 palette=rna_cluster_colors,
                 groups=groups,
                 return_fig=True)
fig.set_size_inches(12, 8)
plt.title(f"NicheCompass Embeddings RNA Cluster Annotations",
          size=20,
          pad=15)

if save_fig:
    fig.savefig(file_path,
                bbox_inches="tight")
else:
    fig.show()

# %%
# Plot UMAP with atac cluster spot annotations
groups = None
save_fig = True
file_path = f"{figure_folder_path}/" \
            "atac_cluster_annotations_latent_space.svg"

fig = sc.pl.umap(model.adata,
                 color=[atac_cluster_key],
                 palette=atac_cluster_colors,
                 groups=groups,
                 return_fig=True)
fig.set_size_inches(12, 8)
plt.title(f"NicheCompass Embeddings ATAC Cluster Annotations",
          size=20,
          pad=15)

if save_fig:
    fig.savefig(file_path,
                bbox_inches="tight")
else:
    fig.show()

# %% [markdown]
# ### 4.2 Identify Niches

# %% [markdown]
# We will compute Leiden clustering based on the NicheCompass embeddings to identify spatial cellular niches.

# %%
# Compute latent Leiden clustering
sc.tl.leiden(adata=model.adata,
             resolution=latent_leiden_resolution,
             key_added=latent_cluster_key,
             neighbors_key=latent_key)

# %%
# Create plot of cell type annotations in physical and latent space
groups = None # set this to a specific cluster for easy visualization, e.g. ["11"]
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"res_{latent_leiden_resolution}_" \
            "latent_clusters_latent_physical_space.svg"

fig = plt.figure(figsize=(12, 14))
title = fig.suptitle(t=f"NicheCompass Latent Clusters " \
                       "in Latent and Physical Space",
                     y=0.96,
                     x=0.55,
                     fontsize=20)
spec1 = gridspec.GridSpec(ncols=1,
                          nrows=2,
                          width_ratios=[1],
                          height_ratios=[3, 2])
spec2 = gridspec.GridSpec(ncols=len(samples),
                          nrows=2,
                          width_ratios=[1] * len(samples),
                          height_ratios=[3, 2])
axs = []
axs.append(fig.add_subplot(spec1[0]))
sc.pl.umap(adata=model.adata,
           color=[latent_cluster_key],
           groups=groups,
           title=f"Latent Clusters in Latent Space",
           ax=axs[0],
           show=False)
for idx, sample in enumerate(samples):
    axs.append(fig.add_subplot(spec2[len(samples) + idx]))
    sc.pl.spatial(adata=model.adata[model.adata.obs[sample_key] == sample],
                  color=[latent_cluster_key],
                  groups=groups,
                  spot_size=30.,
                  title=f"Latent Clusters in Physical Space \n"
                        f"(Sample: {sample})",
                  legend_loc=None,
                  ax=axs[idx+1],
                  show=False)

# Create and position shared legend
handles, labels = axs[0].get_legend_handles_labels()
lgd = fig.legend(handles,
                 labels,
                 loc="center left",
                 bbox_to_anchor=(0.98, 0.5))
axs[0].get_legend().remove()

# Adjust, save and display plot
plt.subplots_adjust(wspace=0.2, hspace=0.25)
if save_fig:
    fig.savefig(file_path,
                bbox_extra_artists=(lgd, title),
                bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 4.3 Analyze Niches

# %% [markdown]
# #### 4.3.1 Niche Composition

# %% [markdown]
# We can analyze the niche composition in terms of rna cluster spot labels.

# %%
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"res_{latent_leiden_resolution}_" \
            f"niche_composition.svg"

df_counts = (model.adata.obs.groupby([latent_cluster_key, rna_cluster_key])
             .size().unstack())
df_counts.plot(kind="bar", stacked=True)
legend = plt.legend(bbox_to_anchor=(1, 1), loc="upper left", prop={'size': 10})
legend.set_title("RNA Cluster", prop={'size': 10})
plt.title("RNA Cluster Composition of Niches")
plt.xlabel("Niche")
plt.ylabel("RNA Cluster Counts")
if save_fig:
    plt.savefig(file_path,
                bbox_extra_artists=(legend,),
                bbox_inches="tight")

# %% [markdown]
# #### 4.3.2 Spot Annotation Neighbor Importances

# %% [markdown]
# Now we will investigate neighbor importances in terms of rna cluster spot labels of different niches.

# %%
# Retrieve node neighbor importances 
# (aggregation weights of the node label aggregator)
model.adata.obsp[agg_weights_key] = model.get_neighbor_importances()

# %%
# Get cell type neighbor importances for each niche / latent cluster
niche_neighbor_importances_df = aggregate_obsp_matrix_per_cell_type(
    adata=model.adata,
    obsp_key=agg_weights_key,
    cell_type_key=rna_cluster_key,
    group_key=latent_cluster_key,
    agg_rows=True)

# %%
display(niche_neighbor_importances_df)

# %%
# Generate chord plots showing cell type neighbor importances
# for each niche / latent cluster
groups = "all"
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"res_{latent_leiden_resolution}_" \
            f"niche_neighbor_importances.png"

create_cell_type_chord_plot_from_df(
        adata=model.adata,
        df=niche_neighbor_importances_df,
        link_threshold=0.01,
        cell_type_key=rna_cluster_key,
        group_key=latent_cluster_key,
        groups=groups,
        plot_label="Niche",
        save_fig=save_fig,
        file_path=file_path)

# %% [markdown]
# ### 4.4 Perform Differential Gene Program Testing

# %% [markdown]
# Now we can test which communication gene programs are differentially expressed in a niche. To this end, we will perform differential gene program testing of a selected niche, e.g. latent cluster / niche "11" (```selected_cats = ["11"]```) vs all other latent clusters / niches (```comparison_cats = "rest"```). However, differential gene program testing can also be performed in the following ways:
# - Set ```selected_cats = None``` to perform differential gene program testing across all niches, as opposed to just for one specific niche.
# - Set ```comparison_cats = ["2", "3"]``` to perform differential gene program testing against latent clusters / niches "2" and "3" as opposed to against all other latent clusters / niches.
#
# We choose a log bayes factor threshold of 4.6 to determine decisively enriched gene programs. Alternatively, the threshold could be loosened to a value of 2.3 to also allow "only" strongly enriched gene programs to be identified (see https://en.wikipedia.org/wiki/Bayes_factor).

# %%
# Check number of active GPs
active_gps = model.get_active_gps()
print(f"Number of total gene programs: {len(model.adata.uns[gp_names_key])}.")
print(f"Number of active gene programs: {len(active_gps)}.")

# %%
# Display example active GPs
gp_summary_df = model.get_gp_summary()
gp_summary_df[gp_summary_df["gp_active"] == True].head()

# %%
# Set parameters for differential gp testing
selected_cats = ["5"]
comparison_cats = "rest"
title = f"NicheCompass Latent Cluster Decisively Enriched Gene Programs"
log_bayes_factor_thresh = 2.3 # 2.3
save_fig = True
file_path = f"{figure_folder_path}/" \
            f"/log_bayes_factor_{log_bayes_factor_thresh}" \
             "_latent_clusters_enriched_gps_dotplot.svg"

# %%
# Run differential gp testing
enriched_gps = model.run_differential_gp_tests(
    cat_key=latent_cluster_key,
    selected_cats=selected_cats,
    comparison_cats=comparison_cats,
    log_bayes_factor_thresh=log_bayes_factor_thresh)

# %%
# Results are stored in a df in the adata object
model.adata.uns[differential_gp_test_results_key]

# %%
# Create dotplot of results
fig = sc.pl.dotplot(model.adata,
                    enriched_gps,
                    groupby=latent_cluster_key,
                    dendrogram=True, 
                    title=title,
                    swap_axes=True,
                    return_fig=True,
                    figsize=(model.adata.obs[latent_cluster_key].nunique() / 2,
                             len(enriched_gps) / 2))
if save_fig:
    fig.savefig(file_path)
else:
    fig.show()

# %%
# Store gene program summary of enriched gene programs
save_file = True
file_path = f"{figure_folder_path}/" \
            f"/log_bayes_factor_{log_bayes_factor_thresh}_" \
            "latent_clusters_enriched_gps_summary.csv"

gp_summary_cols = ["gp_name",
                   "n_source_genes",
                   "n_non_zero_source_genes",
                   "n_target_genes",
                   "n_non_zero_target_genes",
                   "gp_source_genes",
                   "gp_target_genes",
                   "gp_source_genes_weights_sign_corrected",
                   "gp_target_genes_weights_sign_corrected",
                   "gp_source_genes_importances",
                   "gp_target_genes_importances",
                   "n_source_peaks",
                   "n_target_peaks",
                   "gp_source_peaks",
                   "gp_target_peaks",
                   "gp_source_peaks_weights_sign_corrected",
                   "gp_target_peaks_weights_sign_corrected",
                   "gp_source_peaks_importances",
                   "gp_target_peaks_importances"]

enriched_gp_summary_df = gp_summary_df[gp_summary_df["gp_name"].isin(enriched_gps)]
cat_dtype = pd.CategoricalDtype(categories=enriched_gps, ordered=True)
enriched_gp_summary_df.loc[:, "gp_name"] = enriched_gp_summary_df["gp_name"].astype(cat_dtype)
enriched_gp_summary_df = enriched_gp_summary_df.sort_values(by="gp_name")
enriched_gp_summary_df = enriched_gp_summary_df[gp_summary_cols]

if save_file:
    enriched_gp_summary_df.to_csv(f"{file_path}")
else:
    display(enriched_gp_summary_df)

# %% [markdown]
# ### 4.5 Analyze Enriched Gene Programs

# %% [markdown]
# Now we will have a look at the gene program scores as well as the (log normalized) count distributions of
# the most important omics features of the differentially expressed gene programs.

# %%
plot_label = "log_bayes_factor_4.6_cluster_11_vs_rest"
save_figs = True

generate_enriched_gp_info_plots(
    plot_label=plot_label,
    model=model,
    sample_key=sample_key,
    differential_gp_test_results_key=differential_gp_test_results_key,
    cat_key=latent_cluster_key,
    cat_palette=latent_cluster_colors,
    n_top_enriched_gps=10,
    feature_spaces=["p22"], # ["latent"]
    n_top_genes_per_gp=0,
    n_top_peaks_per_gp=5,
    log_norm_omics_features=True,
    save_figs=save_figs,
    figure_folder_path=f"{figure_folder_path}/",
    spot_size=spot_size)
