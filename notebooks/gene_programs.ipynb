# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nichecompass.utils import (extract_gp_dict_from_collectri_tf_network,
                                get_unique_genes_from_gp_dict)

# %%
collectri_gp_dict = extract_gp_dict_from_collectri_tf_network(
        species="mouse",
        tf_network_file_path="../data/gene_programs/collectri_tf_network_mouse.csv",
        load_from_disk=True,
        save_to_disk=False,
        plot_gp_gene_count_distributions=True)

# %%
collectri_genes = get_unique_genes_from_gp_dict(
    gp_dict=collectri_gp_dict,
    retrieved_gene_entities=["sources", "targets"],
    retrieved_gene_categories=["tf"])

# %%
print(len(collectri_gp_dict))
print(len(collectri_genes))
# Out:
# 1072
# 1072
